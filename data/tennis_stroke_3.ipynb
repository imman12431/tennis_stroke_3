# %% [markdown]
# ## Data Collection: Automatic Webcam Image Capture
#
# This cell captures images automatically from a webcam at fixed time intervals and saves them to disk.
# The collected images are intended for later manual labeling and pose analysis.

# %%
import cv2
import os
import uuid
import time

# ----------------------------
# Paths & settings
# ----------------------------
IMAGES_PATH = "data/images_raw"
os.makedirs(IMAGES_PATH, exist_ok=True)
number_images = 200       # total images to capture
delay_between = 0.5      # seconds between captures

# ----------------------------
# Open camera
# ----------------------------
cap = cv2.VideoCapture(1)

# Warm up camera
for _ in range(10):
    ret, frame = cap.read()

print("Capturing images automatically...")

# ----------------------------
# Automatic capture loop
# ----------------------------
imgnum = 0
while imgnum < number_images:
    ret, frame = cap.read()
    if not ret or frame is None:
        continue

    # Display the frame (optional)
    cv2.imshow("Frame", frame)

    # Save image
    imgname = os.path.join(IMAGES_PATH, f"{uuid.uuid1()}.jpg")
    cv2.imwrite(imgname, frame)
    print(f"Saved {imgname}")
    imgnum += 1

    # Wait before next capture
    time.sleep(delay_between)

    # Allow quit with 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# ----------------------------
# Proper cleanup
# ----------------------------
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)  # flush window events
time.sleep(0.1) # ensure window closes
print("Done capturing images! All OpenCV windows closed.")
# Out:
# 2026-01-30 10:02:47.055 Python[73678:29691829] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Capturing images automatically...
# Saved data/images_raw/bb350b2a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bb94f3b4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bbe6c108-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bc3d1c1a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bc982ab0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bce9bcae-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bd407fa8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bd96bc42-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bded205a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/be4377ca-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/be9a2b2e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bef04a72-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bf472a90-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bf9d5870-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/bff386b4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c04a799c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c0a0a308-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c0f678fa-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c147c6ec-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c199d9e6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c1f024f4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c2469708-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c29d4846-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c2f3804e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c349db74-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c3a045b8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c3f70902-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c44d5956-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c4a3b3fa-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c4fa0ade-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c550694c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c5a6d9da-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c5f913a8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c64ea8b8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c6a50c62-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c6fb8bd2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c7524a94-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c7a86118-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c7ff0fae-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c8555abc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c8abbcd6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c901df1c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c953791c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/c9a9da64-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ca009a02-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ca56c9c2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/caad3064-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cafe7230-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cb501ed2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cba65bbc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cbfc8c62-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cc537fcc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cca9a88e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cd001868-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cd567230-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cdad02bc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ce036774-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ce59ce34-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ceb04822-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cf0686ba-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cf5d8834-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/cfb37dc0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d009f254-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d0609dac-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d0b6a756-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d10d6988-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d163a9b0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d1ba17e6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d210933c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d266f31c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d2bd7b6a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d313f47c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d36a97b4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d3c0a58c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d4173866-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d46da084-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d4c3fcfe-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d51a6698-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d5716c40-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d5c74336-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d61dcaf8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d6741e6c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d6ca9058-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d720fb0a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d77778fe-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d7cdf92c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d824993a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d87acae4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d8d139c4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d927a692-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d97e2a8a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/d9d47dc2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/da2af062-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/da8169d8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dad813c8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/db2e3f5a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/db84ada4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dbdb09b0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dc318c0e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dc8810b0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dcde4e94-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dd354b40-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dd8b3b22-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dde1acfa-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/de382260-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/de8e7d04-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dee50eda-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/df3b5506-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/df920680-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/dfe838fc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e03ea020-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e095113a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e0eb8dd0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e141f396-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e198b8f2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e1eee786-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e24560de-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e29b8ffe-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e2f27b48-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e34889de-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e39f0d4a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e3f56b9a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e44bdd4a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e4a27074-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e4f8d25c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e54f382c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e5a5ebf4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e5fc003e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e6527b58-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e6a8d692-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e6ffc2f4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e755bcf4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e7ac6004-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e802cf52-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e8591150-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e8af817a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e905e88a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e95c5a4e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/e9b30844-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ea092a9e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ea5ffa9a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/eab617d6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/eb0c79e6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/eb62f1d6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ebb977c2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ec0fcfaa-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ec661a0e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ecbce690-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ed130a34-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ed6987ce-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/edc00306-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ee16461c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ee6cd13a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/eec35316-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ef19ac8e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/ef700aa2-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/efc67ec8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f01d0fa4-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f0737038-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f0c9cac8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f1203c50-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f176bca6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f1cd1484-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f22398cc-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f279f172-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f2d06246-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f326f034-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f37d55be-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f3d40c4c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f42a1538-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f480a2b8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f4d70e50-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f52d5f76-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f583d41e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f5da73a0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f630b99a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f6873e32-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f6dde07a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f734163e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f78a846a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f7e0ed32-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f8379fba-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f88dce4e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f8e4884c-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f93aae7a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f99112ce-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/f9e794aa-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fa3de2b0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fa94763e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/faeab99a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fb414562-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fb979c5a-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fbee1bca-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fc4487d0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fc9b02b8-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fcf1704e-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fd47afd6-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fd9e2f32-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fdf4db70-fd94-11f0-9cb6-c288c7b5f717.jpg
# Saved data/images_raw/fe4b54a0-fd94-11f0-9cb6-c288c7b5f717.jpg
# Done capturing images! All OpenCV windows closed.

# %%
import cv2
import os

# ----------------------------
# 1. Setup & Paths
# ----------------------------
VIDEO_PATH = "alcaraz.mp4"
OUTPUT_FOLDER = "data/images_raw"

# Create the folder if it doesn't exist
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# ----------------------------
# 2. Extraction Logic
# ----------------------------
cap = cv2.VideoCapture(VIDEO_PATH)

if not cap.isOpened():
    print(f"Error: Could not open video {VIDEO_PATH}")
else:
    fps = cap.get(cv2.CAP_PROP_FPS)
    interval_frames = int(fps / 2)  # Extract every 0.5 seconds
    
    frame_count = 0
    saved_count = 0
    
    # Get the base name of the video to avoid overwriting files from other videos
    video_name = os.path.splitext(os.path.basename(VIDEO_PATH))[0]

    print(f"Extracting frames from {video_name}...")

    while True:
        # Set the position to the specific frame we want
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count)
        ret, frame = cap.read()
        
        if not ret:
            break

        # Generate a unique filename: video_name + frame_index
        file_name = f"{video_name}_frame_{frame_count}.jpg"
        file_path = os.path.join(OUTPUT_FOLDER, file_name)
        
        # Save the image
        cv2.imwrite(file_path, frame)
        
        saved_count += 1
        frame_count += interval_frames

    cap.release()
    print(f"✅ Success! Saved {saved_count} frames to {OUTPUT_FOLDER}")
# Out:
# Extracting frames from alcaraz...
# ✅ Success! Saved 386 frames to data/images_raw

# %% [markdown]
# ## Data Inspection: Random Image Sampling
#
# This cell displays a random subset of images from the collected dataset.
# It is used to quickly verify image quality, framing, and capture consistency.

# %%
import random
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# ----------------------------
# Paths & settings
# ----------------------------
IMAGES_PATH = "data/images_raw"
num_samples = 9  # how many random images to show

# Get all image files
image_files = [f for f in os.listdir(IMAGES_PATH) if f.lower().endswith(('.jpg', '.png'))]

# Pick random samples
sample_files = random.sample(image_files, min(num_samples, len(image_files)))

# ----------------------------
# Plot images in a grid
# ----------------------------
cols = 3
rows = (len(sample_files) + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(12, 8))
axes = axes.flatten()

for ax, img_file in zip(axes, sample_files):
    img_path = os.path.join(IMAGES_PATH, img_file)
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.set_title(img_file)
    ax.axis('off')

# Hide any extra axes
for ax in axes[len(sample_files):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Manual Image Labeling Interface
#
# This cell provides a simple interactive tool to assign categorical labels
# to each image in the dataset and save the annotations as JSON files.

# %%
import os
import json
from IPython.display import display
from PIL import Image
import ipywidgets as widgets

# ----------------------------
# Paths
# ----------------------------
IMAGES_PATH = "data/images_raw"
ANNOTATIONS_PATH = "data/labels"
os.makedirs(ANNOTATIONS_PATH, exist_ok=True)

# 1. Filter: Only get images that DO NOT have a matching JSON file yet
all_images = [f for f in os.listdir(IMAGES_PATH) if f.lower().endswith(('.jpg', '.png'))]
images = [f for f in all_images if not os.path.exists(os.path.join(ANNOTATIONS_PATH, f + ".json"))]
images.sort()

current_idx = 0

# ----------------------------
# Widgets
# ----------------------------
image_widget = widgets.Image()
label_dropdown = widgets.Dropdown(
    options=["backhand", "neutral"],
    description="Label:"
)
next_button = widgets.Button(description="Save & Next", button_style='success')
skip_button = widgets.Button(description="Skip Frame", button_style='warning')
progress_label = widgets.Label()

output = widgets.Output()

def update_display(idx):
    if idx < len(images):
        filename = images[idx]
        path = os.path.join(IMAGES_PATH, filename)
        with open(path, "rb") as f:
            image_widget.value = f.read()
        progress_label.value = f"Image {idx + 1} of {len(images)} (Unlabeled only)"
    else:
        progress_label.value = "🎉 All images labeled!"
        next_button.disabled = True
        skip_button.disabled = True

def save_label(idx):
    filename = images[idx]
    label = label_dropdown.value
    ann_file = os.path.join(ANNOTATIONS_PATH, filename + ".json")
    with open(ann_file, "w") as f:
        json.dump({"image": filename, "label": label}, f)
    with output:
        print(f"✅ Labeled {filename} as {label}")

def on_next(b):
    global current_idx
    output.clear_output()
    save_label(current_idx)
    current_idx += 1
    update_display(current_idx)

def on_skip(b):
    global current_idx
    output.clear_output()
    with output:
        print(f"⏭️ Skipped {images[current_idx]}")
    current_idx += 1
    update_display(current_idx)

next_button.on_click(on_next)
skip_button.on_click(on_skip)

# ----------------------------
# Display Initial State
# ----------------------------
if images:
    update_display(current_idx)
    display(widgets.VBox([progress_label, image_widget, label_dropdown, 
                          widgets.HBox([next_button, skip_button]), output]))
else:
    print("No new images to label! Everything in this folder is already annotated.")
# Out:
# VBox(children=(Label(value='Image 1 of 386 (Unlabeled only)'), Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\…

# %% [markdown]
# ## Visual Verification of Image Labels
#
# This cell displays a random subset of labeled images together with their
# assigned class labels to quickly verify annotation quality and consistency.

# %%
import os
import json
import random
from PIL import Image
import matplotlib.pyplot as plt

IMAGES_PATH = "data/images_raw"
ANNOTATIONS_PATH = "data/labels"

# Load labels
labels = {}
for f in os.listdir(ANNOTATIONS_PATH):
    if f.endswith(".json"):
        with open(os.path.join(ANNOTATIONS_PATH, f)) as jf:
            data = json.load(jf)
            labels[data["image"]] = data["label"]

# Get random sample
images = list(labels.keys())
sample_images = random.sample(images, min(4, len(images)))  # 4 random images

# Display
fig, axes = plt.subplots(2, 2, figsize=(10,10))
axes = axes.flatten()

for ax, img_file in zip(axes, sample_images):
    img_path = os.path.join(IMAGES_PATH, img_file)
    img = Image.open(img_path)
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(f"Label: {labels[img_file]}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pose Extraction and Skeleton Normalization
#
# This cell uses MediaPipe’s Pose Landmarker to extract key body joints from each
# image, normalize joint coordinates relative to body geometry, and pair the
# resulting skeleton data with the corresponding action labels.

# %%
import os
import json
import cv2
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from tqdm.notebook import tqdm

# 1. Paths
IMAGES_PATH = "data/images_raw"
ANNOTATIONS_PATH = "data/labels"
OUTPUT_PATH = "data/skeletons"
MODEL_PATH = 'pose_landmarker_full.task' 
os.makedirs(OUTPUT_PATH, exist_ok=True)

# 2. Updated joints: Added 0, 2, 5 (Face) + your original 8 joints
RELEVANT_JOINTS = [0, 2, 5, 11, 12, 13, 14, 15, 16, 23, 24]

# 3. Setup the Detector
base_options = python.BaseOptions(model_asset_path=MODEL_PATH)
options = vision.PoseLandmarkerOptions(
    base_options=base_options,
    running_mode=vision.RunningMode.IMAGE,
    num_poses=1,
    min_pose_detection_confidence=0.5
)

# 4. Processing Loop
images = sorted([f for f in os.listdir(IMAGES_PATH) if f.lower().endswith((".jpg", ".png"))])
skeletons = []

with vision.PoseLandmarker.create_from_options(options) as landmarker:
    for img_file in tqdm(images, desc="Processing Tennis Images"):
        img_path = os.path.join(IMAGES_PATH, img_file)
        mp_image = mp.Image.create_from_file(img_path)
        result = landmarker.detect(mp_image)

        # Default values if no pose detected
        joints_norm = [[0, 0, 0] for _ in RELEVANT_JOINTS]
        joints_abs = None

        if result.pose_landmarks:
            landmarks = result.pose_landmarks[0]
            h, w = mp_image.height, mp_image.width
            
            # 5. Extract Absolute Coordinates (Exactly as before: full 33 landmarks)
            joints_abs_list = np.array([(lm.x * w, lm.y * h) for lm in landmarks])
            
            # 6. Normalize relative to mid-hip and scale by shoulder width
            left_hip, right_hip = joints_abs_list[23], joints_abs_list[24]
            mid_hip = (left_hip + right_hip) / 2
            
            left_shoulder, right_shoulder = joints_abs_list[11], joints_abs_list[12]
            shoulder_dist = np.linalg.norm(left_shoulder - right_shoulder)
            
            # 7. Filter for RELEVANT_JOINTS and add visibility
            joints_norm = []
            for j in RELEVANT_JOINTS:
                lm = landmarks[j]
                # Calculate normalized X and Y (Exactly as before)
                norm_x = (joints_abs_list[j][0] - mid_hip[0]) / (shoulder_dist if shoulder_dist > 0.001 else 1.0)
                norm_y = (joints_abs_list[j][1] - mid_hip[1]) / (shoulder_dist if shoulder_dist > 0.001 else 1.0)
                
                # Append [x, y, visibility]
                joints_norm.append([float(norm_x), float(norm_y), float(lm.visibility)])

            joints_abs = joints_abs_list.tolist()

        # 8. Pair with your JSON label
        label_file = os.path.join(ANNOTATIONS_PATH, img_file + ".json")
        try:
            with open(label_file) as f:
                label = json.load(f)["label"]
        except FileNotFoundError:
            label = "unlabeled"

        skeletons.append({
            "image": img_file,
            "joints_abs": joints_abs,
            "joints_norm": joints_norm,
            "label": label
        })

# 9. Save final dataset
output_file = os.path.join(OUTPUT_PATH, "skeletons.json")
with open(output_file, "w") as f:
    json.dump(skeletons, f, indent=2)

print(f"✅ Saved {len(skeletons)} skeletons to {output_file}")
# Out:
# I0000 00:00:1769754518.128484 30323306 gl_context.cc:407] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M1
# W0000 00:00:1769754518.205273 30323313 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769754518.234902 30323316 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Processing Tennis Images:   0%|          | 0/586 [00:00<?, ?it/s]
# ✅ Saved 586 skeletons to data/skeletons/skeletons.json

# %% [markdown]
# ## Pose Estimation Verification
#
# This cell visualizes a random subset of images with the estimated pose skeletons overlaid.
# It serves as a sanity check to confirm that joint detection and normalization are working correctly before using the data for modeling.

# %%
import json
import os
import random
import cv2
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------
# Paths & settings
# ----------------------------
IMAGES_PATH = "data/images_raw"
SKELETONS_PATH = "data/skeletons/skeletons.json"
NUM_SAMPLES = 4  # number of random images to visualize

# ----------------------------
# Load skeleton data
# ----------------------------
with open(SKELETONS_PATH, "r") as f:
    skeletons = json.load(f)

# Filter only entries with detected poses
valid_skeletons = [s for s in skeletons if s["joints_abs"] is not None]

# Random sample
samples = random.sample(valid_skeletons, min(NUM_SAMPLES, len(valid_skeletons)))

# ----------------------------
# MediaPipe pose connections (for drawing bones)
# ----------------------------
POSE_CONNECTIONS = [
    (11, 13), (13, 15),   # left arm
    (12, 14), (14, 16),   # right arm
    (11, 12),             # shoulders
    (11, 23), (12, 24),   # torso
    (23, 24)              # hips
]

# ----------------------------
# Plot
# ----------------------------
cols = 2
rows = (len(samples) + cols - 1) // cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
axes = axes.flatten()

for ax, sample in zip(axes, samples):
    img_path = os.path.join(IMAGES_PATH, sample["image"])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    joints = np.array(sample["joints_abs"])

    # Draw joints
    for (x, y) in joints:
        cv2.circle(img, (int(x), int(y)), 5, (0, 255, 0), -1)

    # Draw bones
    for i, j in POSE_CONNECTIONS:
        if i < len(joints) and j < len(joints):
            pt1 = joints[i]
            pt2 = joints[j]
            cv2.line(
                img,
                (int(pt1[0]), int(pt1[1])),
                (int(pt2[0]), int(pt2[1])),
                (255, 0, 0),
                2
            )

    ax.imshow(img)
    ax.set_title(f"Label: {sample['label']}")
    ax.axis("off")

# Hide unused axes
for ax in axes[len(samples):]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Definition & Training
# This cell defines a **Multilayer Perceptron (MLP)** architecture tailored for classified body pose coordinates.
# It processes the normalized joint data, trains the network using backpropagation, and evaluates the final accuracy to ensure the model can effectively distinguish between different tennis strokes.

# %%
import json
import numpy as np
import os
import joblib
import random
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

# ----------------------------
# 1. Load and Randomize Data
# ----------------------------
DATA_PATH = "data/skeletons/skeletons.json"
with open(DATA_PATH) as f:
    data = json.load(f)

# Pair X and y for a clean shuffle
combined_data = []
for sample in data:
    if sample["label"] == "unlabeled": 
        continue
    
    # Flatten the (11, 3) matrix into a (33,) vector
    features = np.array(sample["joints_norm"]).flatten()
    combined_data.append((features, sample["label"]))

# RANDOMIZE: This ensures backhands and neutrals are mixed together
random.seed(42)
random.shuffle(combined_data)

X = np.array([item[0] for item in combined_data], dtype=np.float32)
y = np.array([item[1] for item in combined_data])

# ----------------------------
# 2. Preprocessing
# ----------------------------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
backhand_idx = list(le.classes_).index('backhand')
neutral_idx = list(le.classes_).index('neutral')

# Stratify ensures the 1:2.2 ratio is identical in Train and Test
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# ----------------------------
# 3. Class Weights (The "Hammer")
# ----------------------------
# We stick with 3.0 because it successfully stopped the "Everything is Neutral" bug
class_weight_dict = {
    neutral_idx: 1.0,
    backhand_idx: 3.0  
}

print(f"Backhand Index: {backhand_idx} | Weights: {class_weight_dict}")

# ----------------------------
# 4. Build Model (Updated for 33 inputs)
# ----------------------------
model = models.Sequential([
    # Input shape is now 33 (11 joints * [x, y, vis])
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(33,)),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.2),
    layers.Dense(len(le.classes_), activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ----------------------------
# 5. Train
# ----------------------------
early_stop = callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=50, # Increased patience to allow more time to learn with face data
    restore_best_weights=True
)

print("\nStarting Training...")
model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=16,
    validation_data=(X_test, y_test),
    class_weight=class_weight_dict,
    callbacks=[early_stop],
    verbose=1
)

# ----------------------------
# 6. Save & Evaluate (Newer SavedModel format)
# ----------------------------
MODEL_DIR = "models/tennis_stroke"
os.makedirs(MODEL_DIR, exist_ok=True)

# Save the model in the new SavedModel format
MODEL_PATH = os.path.join(MODEL_DIR, "tennis_model_keras")  # folder, not .h5
model.save(MODEL_PATH, save_format="tf")  # "tf" indicates SavedModel format

# Save the label encoder as before
joblib.dump(le, os.path.join(MODEL_DIR, "label_encoder_keras.pkl"))

# Evaluate and print classification report
y_pred = np.argmax(model.predict(X_test), axis=1)
print("\nFinal Classification Report (33 Inputs):")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Backhand Index: 0 | Weights: {1: 1.0, 0: 3.0}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Starting Training...
# Epoch 1/300
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3555 - accuracy: 0.5993 - val_loss: 0.4764 - val_accuracy: 0.8310
# Epoch 2/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8171 - accuracy: 0.7766 - val_loss: 0.4185 - val_accuracy: 0.8028
# Epoch 3/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7221 - accuracy: 0.8014 - val_loss: 0.3927 - val_accuracy: 0.8310
# Epoch 4/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6134 - accuracy: 0.8085 - val_loss: 0.3530 - val_accuracy: 0.8451
# Epoch 5/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6858 - accuracy: 0.8085 - val_loss: 0.3584 - val_accuracy: 0.8451
# Epoch 6/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6050 - accuracy: 0.8227 - val_loss: 0.3631 - val_accuracy: 0.8310
# Epoch 7/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6064 - accuracy: 0.8227 - val_loss: 0.3245 - val_accuracy: 0.8732
# Epoch 8/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.8794 - val_loss: 0.3261 - val_accuracy: 0.8732
# Epoch 9/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6041 - accuracy: 0.8830 - val_loss: 0.3404 - val_accuracy: 0.8592
# Epoch 10/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5162 - accuracy: 0.8617 - val_loss: 0.3299 - val_accuracy: 0.9014
# Epoch 11/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4669 - accuracy: 0.9149 - val_loss: 0.2747 - val_accuracy: 0.9296
# Epoch 12/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.9078 - val_loss: 0.2638 - val_accuracy: 0.9296
# Epoch 13/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.9255 - val_loss: 0.2401 - val_accuracy: 0.9296
# Epoch 14/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.9043 - val_loss: 0.3164 - val_accuracy: 0.9014
# Epoch 15/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.9043 - val_loss: 0.2577 - val_accuracy: 0.9296
# Epoch 16/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.9326 - val_loss: 0.2598 - val_accuracy: 0.9296
# Epoch 17/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3770 - accuracy: 0.9291 - val_loss: 0.2685 - val_accuracy: 0.9296
# Epoch 18/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.9326 - val_loss: 0.2281 - val_accuracy: 0.9296
# Epoch 19/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3699 - accuracy: 0.9326 - val_loss: 0.2311 - val_accuracy: 0.9296
# Epoch 20/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4276 - accuracy: 0.9362 - val_loss: 0.2411 - val_accuracy: 0.9296
# Epoch 21/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4059 - accuracy: 0.9397 - val_loss: 0.2381 - val_accuracy: 0.9437
# Epoch 22/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3672 - accuracy: 0.9255 - val_loss: 0.2545 - val_accuracy: 0.9296
# Epoch 23/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4110 - accuracy: 0.9362 - val_loss: 0.2230 - val_accuracy: 0.9437
# Epoch 24/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4046 - accuracy: 0.9362 - val_loss: 0.2665 - val_accuracy: 0.9296
# Epoch 25/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3172 - accuracy: 0.9539 - val_loss: 0.2152 - val_accuracy: 0.9577
# Epoch 26/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3669 - accuracy: 0.9433 - val_loss: 0.2503 - val_accuracy: 0.9296
# Epoch 27/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.9468 - val_loss: 0.2370 - val_accuracy: 0.9437
# Epoch 28/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3583 - accuracy: 0.9291 - val_loss: 0.2245 - val_accuracy: 0.9296
# Epoch 29/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3663 - accuracy: 0.9433 - val_loss: 0.2239 - val_accuracy: 0.9437
# Epoch 30/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.9326 - val_loss: 0.2326 - val_accuracy: 0.9437
# Epoch 31/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3566 - accuracy: 0.9468 - val_loss: 0.2284 - val_accuracy: 0.9437
# Epoch 32/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.9397 - val_loss: 0.2161 - val_accuracy: 0.9577
# Epoch 33/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.9397 - val_loss: 0.2357 - val_accuracy: 0.9437
# Epoch 34/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3131 - accuracy: 0.9468 - val_loss: 0.2139 - val_accuracy: 0.9577
# Epoch 35/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3345 - accuracy: 0.9468 - val_loss: 0.2164 - val_accuracy: 0.9296
# Epoch 36/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3339 - accuracy: 0.9397 - val_loss: 0.2213 - val_accuracy: 0.9437
# Epoch 37/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2941 - accuracy: 0.9574 - val_loss: 0.2164 - val_accuracy: 0.9296
# Epoch 38/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2807 - accuracy: 0.9610 - val_loss: 0.1946 - val_accuracy: 0.9577
# Epoch 39/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.9610 - val_loss: 0.2214 - val_accuracy: 0.9296
# Epoch 40/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3057 - accuracy: 0.9362 - val_loss: 0.2156 - val_accuracy: 0.9577
# Epoch 41/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3201 - accuracy: 0.9362 - val_loss: 0.2077 - val_accuracy: 0.9437
# Epoch 42/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.9504 - val_loss: 0.1862 - val_accuracy: 0.9577
# Epoch 43/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2899 - accuracy: 0.9574 - val_loss: 0.1941 - val_accuracy: 0.9577
# Epoch 44/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2853 - accuracy: 0.9539 - val_loss: 0.1834 - val_accuracy: 0.9577
# Epoch 45/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.9645 - val_loss: 0.1921 - val_accuracy: 0.9577
# Epoch 46/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3175 - accuracy: 0.9504 - val_loss: 0.1958 - val_accuracy: 0.9437
# Epoch 47/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2853 - accuracy: 0.9610 - val_loss: 0.1964 - val_accuracy: 0.9437
# Epoch 48/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2685 - accuracy: 0.9468 - val_loss: 0.2105 - val_accuracy: 0.9296
# Epoch 49/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2717 - accuracy: 0.9468 - val_loss: 0.1936 - val_accuracy: 0.9437
# Epoch 50/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 0.9504 - val_loss: 0.1901 - val_accuracy: 0.9577
# Epoch 51/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.9397 - val_loss: 0.1873 - val_accuracy: 0.9577
# Epoch 52/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.9610 - val_loss: 0.1840 - val_accuracy: 0.9577
# Epoch 53/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.9610 - val_loss: 0.1862 - val_accuracy: 0.9718
# Epoch 54/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2229 - accuracy: 0.9716 - val_loss: 0.1865 - val_accuracy: 0.9718
# Epoch 55/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3011 - accuracy: 0.9433 - val_loss: 0.1960 - val_accuracy: 0.9437
# Epoch 56/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.9468 - val_loss: 0.1886 - val_accuracy: 0.9718
# Epoch 57/300
# 18/18 [==============================] - 0s 998us/step - loss: 0.2678 - accuracy: 0.9468 - val_loss: 0.1822 - val_accuracy: 0.9437
# Epoch 58/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2342 - accuracy: 0.9539 - val_loss: 0.1792 - val_accuracy: 0.9718
# Epoch 59/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2710 - accuracy: 0.9574 - val_loss: 0.1845 - val_accuracy: 0.9437
# Epoch 60/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2356 - accuracy: 0.9645 - val_loss: 0.1935 - val_accuracy: 0.9577
# Epoch 61/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2547 - accuracy: 0.9681 - val_loss: 0.1897 - val_accuracy: 0.9577
# Epoch 62/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.9539 - val_loss: 0.1895 - val_accuracy: 0.9718
# Epoch 63/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.9539 - val_loss: 0.1943 - val_accuracy: 0.9718
# Epoch 64/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2110 - accuracy: 0.9645 - val_loss: 0.1898 - val_accuracy: 0.9577
# Epoch 65/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9574 - val_loss: 0.1835 - val_accuracy: 0.9577
# Epoch 66/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9574 - val_loss: 0.1872 - val_accuracy: 0.9718
# Epoch 67/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.9539 - val_loss: 0.1816 - val_accuracy: 0.9577
# Epoch 68/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2453 - accuracy: 0.9539 - val_loss: 0.1808 - val_accuracy: 0.9577
# Epoch 69/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2306 - accuracy: 0.9574 - val_loss: 0.1980 - val_accuracy: 0.9718
# Epoch 70/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.9539 - val_loss: 0.1863 - val_accuracy: 0.9577
# Epoch 71/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2213 - accuracy: 0.9645 - val_loss: 0.1808 - val_accuracy: 0.9718
# Epoch 72/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2113 - accuracy: 0.9645 - val_loss: 0.1875 - val_accuracy: 0.9577
# Epoch 73/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2538 - accuracy: 0.9504 - val_loss: 0.1966 - val_accuracy: 0.9577
# Epoch 74/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2123 - accuracy: 0.9645 - val_loss: 0.1934 - val_accuracy: 0.9718
# Epoch 75/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.9610 - val_loss: 0.2012 - val_accuracy: 0.9296
# Epoch 76/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9468 - val_loss: 0.1746 - val_accuracy: 0.9577
# Epoch 77/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9716 - val_loss: 0.1786 - val_accuracy: 0.9718
# Epoch 78/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.9610 - val_loss: 0.1764 - val_accuracy: 0.9718
# Epoch 79/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.9574 - val_loss: 0.1800 - val_accuracy: 0.9718
# Epoch 80/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2301 - accuracy: 0.9574 - val_loss: 0.1973 - val_accuracy: 0.9718
# Epoch 81/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.9504 - val_loss: 0.1961 - val_accuracy: 0.9718
# Epoch 82/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9574 - val_loss: 0.2088 - val_accuracy: 0.9577
# Epoch 83/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2172 - accuracy: 0.9574 - val_loss: 0.1834 - val_accuracy: 0.9718
# Epoch 84/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2158 - accuracy: 0.9574 - val_loss: 0.2011 - val_accuracy: 0.9718
# Epoch 85/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.9610 - val_loss: 0.1849 - val_accuracy: 0.9718
# Epoch 86/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2141 - accuracy: 0.9645 - val_loss: 0.1682 - val_accuracy: 0.9577
# Epoch 87/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9539 - val_loss: 0.1886 - val_accuracy: 0.9718
# Epoch 88/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2091 - accuracy: 0.9574 - val_loss: 0.1848 - val_accuracy: 0.9718
# Epoch 89/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2356 - accuracy: 0.9610 - val_loss: 0.1946 - val_accuracy: 0.9577
# Epoch 90/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.9752 - val_loss: 0.1997 - val_accuracy: 0.9718
# Epoch 91/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2092 - accuracy: 0.9681 - val_loss: 0.1914 - val_accuracy: 0.9577
# Epoch 92/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2451 - accuracy: 0.9539 - val_loss: 0.1890 - val_accuracy: 0.9718
# Epoch 93/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1915 - accuracy: 0.9681 - val_loss: 0.1879 - val_accuracy: 0.9718
# Epoch 94/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 0.9610 - val_loss: 0.1881 - val_accuracy: 0.9718
# Epoch 95/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2012 - accuracy: 0.9610 - val_loss: 0.1798 - val_accuracy: 0.9718
# Epoch 96/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9681 - val_loss: 0.1741 - val_accuracy: 0.9577
# Epoch 97/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 0.9681 - val_loss: 0.1997 - val_accuracy: 0.9577
# Epoch 98/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2235 - accuracy: 0.9504 - val_loss: 0.1901 - val_accuracy: 0.9718
# Epoch 99/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.9645 - val_loss: 0.1826 - val_accuracy: 0.9437
# Epoch 100/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9716 - val_loss: 0.1794 - val_accuracy: 0.9437
# Epoch 101/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1949 - accuracy: 0.9681 - val_loss: 0.1862 - val_accuracy: 0.9718
# Epoch 102/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9645 - val_loss: 0.2083 - val_accuracy: 0.9437
# Epoch 103/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9681 - val_loss: 0.2122 - val_accuracy: 0.9577
# Epoch 104/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1746 - accuracy: 0.9787 - val_loss: 0.1954 - val_accuracy: 0.9718
# Epoch 105/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2106 - accuracy: 0.9610 - val_loss: 0.1827 - val_accuracy: 0.9718
# Epoch 106/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2281 - accuracy: 0.9610 - val_loss: 0.1981 - val_accuracy: 0.9718
# Epoch 107/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2176 - accuracy: 0.9539 - val_loss: 0.1814 - val_accuracy: 0.9437
# Epoch 108/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9787 - val_loss: 0.1865 - val_accuracy: 0.9577
# Epoch 109/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1750 - accuracy: 0.9823 - val_loss: 0.1930 - val_accuracy: 0.9718
# Epoch 110/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9574 - val_loss: 0.1778 - val_accuracy: 0.9437
# Epoch 111/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9610 - val_loss: 0.1862 - val_accuracy: 0.9718
# Epoch 112/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2088 - accuracy: 0.9574 - val_loss: 0.1851 - val_accuracy: 0.9718
# Epoch 113/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1738 - accuracy: 0.9681 - val_loss: 0.2038 - val_accuracy: 0.9718
# Epoch 114/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1697 - accuracy: 0.9823 - val_loss: 0.2026 - val_accuracy: 0.9718
# Epoch 115/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1835 - accuracy: 0.9716 - val_loss: 0.1932 - val_accuracy: 0.9718
# Epoch 116/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1953 - accuracy: 0.9645 - val_loss: 0.1882 - val_accuracy: 0.9718
# Epoch 117/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1720 - accuracy: 0.9752 - val_loss: 0.1840 - val_accuracy: 0.9718
# Epoch 118/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9610 - val_loss: 0.2091 - val_accuracy: 0.9718
# Epoch 119/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1889 - accuracy: 0.9645 - val_loss: 0.2004 - val_accuracy: 0.9577
# Epoch 120/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9645 - val_loss: 0.2079 - val_accuracy: 0.9577
# Epoch 121/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1906 - accuracy: 0.9645 - val_loss: 0.2046 - val_accuracy: 0.9577
# Epoch 122/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9645 - val_loss: 0.2054 - val_accuracy: 0.9718
# Epoch 123/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9645 - val_loss: 0.1741 - val_accuracy: 0.9718
# Epoch 124/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1939 - accuracy: 0.9645 - val_loss: 0.2077 - val_accuracy: 0.9718
# Epoch 125/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1868 - accuracy: 0.9681 - val_loss: 0.1898 - val_accuracy: 0.9718
# Epoch 126/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1655 - accuracy: 0.9681 - val_loss: 0.2017 - val_accuracy: 0.9577
# Epoch 127/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9681 - val_loss: 0.1942 - val_accuracy: 0.9718
# Epoch 128/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9681 - val_loss: 0.1872 - val_accuracy: 0.9718
# Epoch 129/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2177 - accuracy: 0.9645 - val_loss: 0.1822 - val_accuracy: 0.9718
# Epoch 130/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2098 - accuracy: 0.9574 - val_loss: 0.1811 - val_accuracy: 0.9718
# Epoch 131/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9716 - val_loss: 0.1878 - val_accuracy: 0.9718
# Epoch 132/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1893 - accuracy: 0.9752 - val_loss: 0.1946 - val_accuracy: 0.9718
# Epoch 133/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1603 - accuracy: 0.9681 - val_loss: 0.1777 - val_accuracy: 0.9718
# Epoch 134/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9681 - val_loss: 0.1886 - val_accuracy: 0.9718
# Epoch 135/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9752 - val_loss: 0.1878 - val_accuracy: 0.9718
# Epoch 136/300
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1786 - accuracy: 0.9645 - val_loss: 0.2120 - val_accuracy: 0.9718
# INFO:tensorflow:Assets written to: models/tennis_stroke/tennis_model_keras/assets
# INFO:tensorflow:Assets written to: models/tennis_stroke/tennis_model_keras/assets
# 3/3 [==============================] - 0s 680us/step
#
# Final Classification Report (33 Inputs):
#               precision    recall  f1-score   support
#
#     backhand       0.95      0.91      0.93        22
#      neutral       0.96      0.98      0.97        49
#
#     accuracy                           0.96        71
#    macro avg       0.96      0.94      0.95        71
# weighted avg       0.96      0.96      0.96        71

# %% [markdown]
# # Main Model Inference and Visual Validation
# ### Skeleton-Based Action Classification with Coordinate Normalization
# ---

# %%
import tensorflow as tf
import cv2
import os
import random
import numpy as np
import joblib
import matplotlib.pyplot as plt
import urllib.request
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# ----------------------------
# 1. Setup & Auto-Download Model
# ----------------------------
MODEL_ASSET_PATH = 'pose_landmarker_heavy.task'
MODEL_URL = "https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_heavy/float16/1/pose_landmarker_heavy.task"

if not os.path.exists(MODEL_ASSET_PATH):
    print(f"Downloading {MODEL_ASSET_PATH}...")
    urllib.request.urlretrieve(MODEL_URL, MODEL_ASSET_PATH)

KERAS_MODEL_PATH = "models/tennis_stroke/tennis_model_keras"
ENCODER_PATH = "models/tennis_stroke/label_encoder_keras.pkl"

keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
le = joblib.load(ENCODER_PATH)

# ----------------------------
# 2. Configure MediaPipe Task
# ----------------------------
options = vision.PoseLandmarkerOptions(
    base_options=python.BaseOptions(model_asset_path=MODEL_ASSET_PATH),
    running_mode=vision.RunningMode.IMAGE)

# ----------------------------
# 3. Pick a Random Image
# ----------------------------
IMAGES_PATH = "data/images_raw"
all_images = [f for f in os.listdir(IMAGES_PATH) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
random_img_name = random.choice(all_images)
img_path = os.path.join(IMAGES_PATH, random_img_name)

# ----------------------------
# 4. Run Inference with Normalization
# ----------------------------
with vision.PoseLandmarker.create_from_options(options) as landmarker:
    mp_image = mp.Image.create_from_file(img_path)
    detection_result = landmarker.detect(mp_image)

    if detection_result.pose_landmarks:
        pose_landmarks = detection_result.pose_landmarks[0]
        h, w = mp_image.height, mp_image.width
        
        # We need ALL landmarks to calculate the mid-hip and shoulder distance
        all_coords = np.array([(lm.x * w, lm.y * h) for lm in pose_landmarks])
        
        # 1. Calculate Normalization Factors (Exactly like training)
        left_hip, right_hip = all_coords[23], all_coords[24]
        mid_hip = (left_hip + right_hip) / 2
        
        left_shoulder, right_shoulder = all_coords[11], all_coords[12]
        shoulder_dist = np.linalg.norm(left_shoulder - right_shoulder)
        if shoulder_dist < 0.001: shoulder_dist = 1.0 # Prevent division by zero

        # 2. Extract 11 Joints (33 values: x, y, visibility)
        relevant_indices = [0, 2, 5, 11, 12, 13, 14, 15, 16, 23, 24]
        input_vector = []
        
        for idx in relevant_indices:
            lm = pose_landmarks[idx]
            # Normalize X and Y relative to hip and shoulder scale
            norm_x = (all_coords[idx][0] - mid_hip[0]) / shoulder_dist
            norm_y = (all_coords[idx][1] - mid_hip[1]) / shoulder_dist
            
            input_vector.extend([float(norm_x), float(norm_y), float(lm.visibility)])
            
        # 3. Keras Prediction
        input_data = np.array([input_vector], dtype=np.float32)
        predictions = keras_model.predict(input_data, verbose=0)
        class_idx = np.argmax(predictions)
        confidence = np.max(predictions)
        label = le.inverse_transform([class_idx])[0]

        # ----------------------------
        # 5. Visualization
        # ----------------------------
        output_image = mp_image.numpy_view()
        plt.figure(figsize=(10, 8))
        plt.imshow(output_image)
        
        # Plot the 11 joints used for prediction
        for idx in relevant_indices:
            px_x, px_y = int(all_coords[idx][0]), int(all_coords[idx][1])
            plt.scatter(px_x, px_y, c='yellow', edgecolors='black', s=70, zorder=3)

        title_color = 'blue' if label.lower() == 'backhand' else 'green'
        plt.title(f"Prediction: {label.upper()} ({confidence:.2%})\nFile: {random_img_name}", 
                  fontsize=14, fontweight='bold', color=title_color)
        plt.axis('off')
        plt.show()
    else:
        print(f"No pose detected in {random_img_name}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770201278.150809       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# # Primary Action Recognition and Automated Video Segmentation
# ### Skeleton-Based Motion Analysis for Real-Time Event Detection and Storage
# ---

# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import joblib
import os
from collections import deque
from mediapipe.tasks import python

# ----------------------------
# 1. Config & Paths
# ----------------------------
VIDEO_PATH = "r.mp4"
OUTPUT_FOLDER = "backhand_clips"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

MODEL_ASSET_PATH = 'pose_landmarker_heavy.task'
KERAS_MODEL_PATH = "models/tennis_stroke/tennis_model_keras.h5"
ENCODER_PATH = "models/tennis_stroke/label_encoder_keras.pkl"

keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
le = joblib.load(ENCODER_PATH)

# ----------------------------
# 2. MediaPipe & Video Setup
# ----------------------------
base_options = python.BaseOptions(model_asset_path=MODEL_ASSET_PATH)
options = mp.tasks.vision.PoseLandmarkerOptions(
    base_options=base_options,
    running_mode=mp.tasks.vision.RunningMode.VIDEO)

cap = cv2.VideoCapture(VIDEO_PATH)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Buffer for "before" clip (1 second)
buffer_size = fps 
frame_buffer = deque(maxlen=buffer_size)

# ----------------------------
# 3. Processing Loop
# ----------------------------
print(f"Analyzing video... (Scanning for backhands)")

with mp.tasks.vision.PoseLandmarker.create_from_options(options) as landmarker:
    frame_count = 0
    clip_count = 0
    frames_to_record = 0
    current_writer = None
    cooldown_frames = 0 

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break

        timestamp_ms = int(1000 * frame_count / fps)
        frame_count += 1
        
        # We always add to the buffer so the "past" is always fresh
        frame_buffer.append(frame.copy())
        
        if cooldown_frames > 0: cooldown_frames -= 1
        
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        result = landmarker.detect_for_video(mp_image, timestamp_ms)

        is_backhand = False
        if result.pose_landmarks:
            landmarks = result.pose_landmarks[0]
            all_coords = np.array([(lm.x * width, lm.y * height) for lm in landmarks])
            mid_hip = (all_coords[23] + all_coords[24]) / 2
            shoulder_dist = np.linalg.norm(all_coords[11] - all_coords[12])
            if shoulder_dist < 0.001: shoulder_dist = 1.0

            relevant_indices = [0, 2, 5, 11, 12, 13, 14, 15, 16, 23, 24]
            input_vector = []
            for idx in relevant_indices:
                lm = landmarks[idx]
                norm_x = (all_coords[idx][0] - mid_hip[0]) / shoulder_dist
                norm_y = (all_coords[idx][1] - mid_hip[1]) / shoulder_dist
                input_vector.extend([float(norm_x), float(norm_y), float(lm.visibility)])
            
            input_data = np.array([input_vector], dtype=np.float32)
            preds = keras_model.predict_on_batch(input_data)
            class_idx = np.argmax(preds[0])
            confidence = preds[0][class_idx]
            label = le.inverse_transform([class_idx])[0]
            
            if label.lower() == "backhand" and confidence > 0.85 and cooldown_frames == 0:
                is_backhand = True

        # ----------------------------
        # 4. Logic: Improved Saving Logic
        # ----------------------------
        
        # Start a new recording
        if is_backhand and frames_to_record <= 0:
            clip_count += 1
            clip_name = os.path.join(OUTPUT_FOLDER, f"backhand_{clip_count}.mp4")
            current_writer = cv2.VideoWriter(clip_name, fourcc, fps, (width, height))
            
            # Write everything in the buffer (the 1s before)
            for buf_frame in frame_buffer:
                current_writer.write(buf_frame)
            
            frames_to_record = int(fps * 1.5) 
            cooldown_frames = fps * 2
            print(f"  >> Captured backhand #{clip_count} at {frame_count/fps:.1f}s")

        # Continue recording current clip
        elif frames_to_record > 0:
            current_writer.write(frame)
            frames_to_record -= 1
            
            # Close the writer when done
            if frames_to_record == 0:
                current_writer.release()
                current_writer = None

cap.release()
if current_writer: current_writer.release()
print(f"\n✅ Done! Found {clip_count} backhand(s).")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# I0000 00:00:1769765297.162864 30464413 gl_context.cc:407] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M1
# W0000 00:00:1769765297.213662 30464414 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769765297.289644 30464414 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Analyzing video... (Scanning for backhands)
#   >> Captured backhand #1 at 2.1s
#   >> Captured backhand #2 at 4.1s
#   >> Captured backhand #3 at 6.3s
#   >> Captured backhand #4 at 11.3s
#   >> Captured backhand #5 at 15.3s
#   >> Captured backhand #6 at 18.2s
#   >> Captured backhand #7 at 20.7s
#   >> Captured backhand #8 at 25.7s
#   >> Captured backhand #9 at 28.2s
#   >> Captured backhand #10 at 31.1s
#   >> Captured backhand #11 at 38.9s
#   >> Captured backhand #12 at 46.4s
#   >> Captured backhand #13 at 49.0s
#   >> Captured backhand #14 at 52.1s
#   >> Captured backhand #15 at 55.8s
#
# ✅ Done! Found 15 backhand(s).

# %% [markdown]
# # Tennis Dataset Integrity and Distribution Analysis
# ### Automated Audit of Class Balance for Neural Network Optimization
# ---

# %%
import json
import os
from collections import Counter

# 1. Path to your combined dataset
SKELETON_FILE = "data/skeletons/skeletons.json"

if not os.path.exists(SKELETON_FILE):
    print(f"Error: Could not find {SKELETON_FILE}")
else:
    with open(SKELETON_FILE, 'r') as f:
        data = json.load(f)

    # 2. Extract all labels
    labels = [item.get('label', 'unlabeled') for item in data]
    total = len(labels)
    counts = Counter(labels)

    # 3. Print a clean summary
    print("-" * 30)
    print(f"DATASET SUMMARY: {total} total samples")
    print("-" * 30)
    
    for label, count in counts.items():
        percentage = (count / total) * 100
        print(f"{label.upper():<12}: {count:>4}  ({percentage:>5.1f}%)")
    
    print("-" * 30)

    # 4. Strategic Advice
    backhand_count = counts.get('backhand', 0)
    neutral_count = counts.get('neutral', 0)
    
    if total > 0:
        ratio = neutral_count / (backhand_count if backhand_count > 0 else 1)
        
        if ratio > 4:
            print(f"⚠️  WARNING: Skew is too high! (Ratio 1:{ratio:.1f})")
            print("Your model will likely struggle to find backhands.")
            print(f"Advice: Label at least {int(neutral_count/2) - backhand_count} more backhands.")
        elif 'unlabeled' in counts:
            print(f"💡 TIP: You have {counts['unlabeled']} unlabeled skeletons.")
            print("Labeling these might help balance the scales.")
        else:
            print("✅ Dataset balance looks manageable for training with class weights.")
# Out:
# ------------------------------
# DATASET SUMMARY: 353 total samples
# ------------------------------
# BACKHAND    :  109  ( 30.9%)
# NEUTRAL     :  244  ( 69.1%)
# ------------------------------
# ✅ Dataset balance looks manageable for training with class weights.

# %%
import json
import os
import random

# 1. Path to your dataset
SKELETON_FILE = "data/skeletons/skeletons.json"
BACKUP_FILE = "data/skeletons/skeletons_backup.json"

if not os.path.exists(SKELETON_FILE):
    print(f"Error: Could not find {SKELETON_FILE}")
else:
    with open(SKELETON_FILE, 'r') as f:
        data = json.load(f)

    # Create a backup just in case
    with open(BACKUP_FILE, 'w') as f:
        json.dump(data, f, indent=2)
    print(f"Backup created at {BACKUP_FILE}")

    # 2. Separate the classes
    backhands = [item for item in data if item.get('label') == 'backhand']
    neutrals = [item for item in data if item.get('label') == 'neutral']
    # Note: Unlabeled items are ignored/dropped here

    print(f"Current state: {len(backhands)} Backhands, {len(neutrals)} Neutrals")

    # 3. Prune Neutrals
    # We want to remove 200, but we check if we actually have that many
    num_to_remove = min(200, len(neutrals))
    
    # Randomly shuffle and remove
    random.seed(42) # For reproducible results
    random.shuffle(neutrals)
    pruned_neutrals = neutrals[num_to_remove:] # Keep everything AFTER the first 200

    # 4. Merge and Save
    new_data = backhands + pruned_neutrals
    
    with open(SKELETON_FILE, 'w') as f:
        json.dump(new_data, f, indent=2)

    print("-" * 30)
    print("CLEANUP COMPLETE")
    print("-" * 30)
    print(f"Removed: 200 Neutral instances")
    print(f"Removed: All Unlabeled instances")
    print(f"New Total: {len(new_data)} samples")
    print(f"New Ratio: 1 : {len(pruned_neutrals)/len(backhands):.1f}")
    print("-" * 30)
# Out:
# Backup created at data/skeletons/skeletons_backup.json
# Current state: 109 Backhands, 444 Neutrals
# ------------------------------
# CLEANUP COMPLETE
# ------------------------------
# Removed: 200 Neutral instances
# Removed: All Unlabeled instances
# New Total: 353 samples
# New Ratio: 1 : 2.2
# ------------------------------

# %% [markdown]
# # Image Expert Dataset Preparation and Preprocessing
# ### Transformation of Raw Footage into Normalized Tensor Inputs for CNN Training
# ---

# %%
import os
import json
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Config
JSON_PATH = "data/skeletons/skeletons.json"
IMAGES_DIR = "data/images_raw"
IMG_SIZE = 224 

def prepare_expert_dataset():
    with open(JSON_PATH, 'r') as f:
        data = json.load(f)

    img_features = []
    img_labels = []
    
    print("Loading full-frame images for Image Expert...")
    for sample in data:
        if sample["label"] == "unlabeled": continue
        
        img_path = os.path.join(IMAGES_DIR, sample["image"])
        if not os.path.exists(img_path): continue

        # Load and preprocess
        raw_bgr = cv2.imread(img_path)
        if raw_bgr is None: continue
        
        rgb_img = cv2.cvtColor(raw_bgr, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE)) 
        
        # Normalize to [-1, 1] for MobileNetV2 compatibility
        normalized_img = (resized_img.astype(np.float32) / 127.5) - 1.0

        img_features.append(normalized_img)
        img_labels.append(1 if sample["label"] == "backhand" else 0)

    return np.array(img_features), np.array(img_labels)

# Load the data
img_features, img_labels = prepare_expert_dataset()

# Split into train and test sets
img_train, img_test, label_train, label_test = train_test_split(
    img_features, img_labels, test_size=0.2, stratify=img_labels, random_state=42
)
# Out:
# Loading full-frame images for Image Expert...

# %% [markdown]
# # Convolutional Neural Network Architecture Design
# ### Implementing Transfer Learning with MobileNetV2 for Binary Feature Extraction
# ---

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications

def build_expert_cnn():
    base_model = applications.MobileNetV2(
        input_shape=(224, 224, 3),
        include_top=False,
        weights="imagenet"
    )

    # Fine-tune only top layers
    base_model.trainable = True
    for layer in base_model.layers[:-40]:
        layer.trainable = False

    inputs = tf.keras.Input(shape=(224, 224, 3))

    # Light augmentation (safe for tennis)
    x = layers.RandomFlip("horizontal")(inputs)
    x = layers.RandomRotation(0.05)(x)
    x = layers.RandomZoom(0.1)(x)

    # IMPORTANT: NO preprocess_input here
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-5),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %% [markdown]
# # Image Expert Training and Model Export
# ### Execution of Supervised Learning with Weighted Binary Cross-Entropy
# ---

# %%
model = build_expert_cnn()

class_weights = {
    0: 1.0,   # not_backhand
    1: 1.8    # backhand (precision-biased)
}

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_precision",
        mode="max",
        patience=5,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "models/tennis_stroke/image_expert_v2.keras",
        monitor="val_precision",
        mode="max",
        save_best_only=True
    )
]

history = model.fit(
    img_train,
    label_train,
    validation_data=(img_test, label_test),
    epochs=30,
    batch_size=16,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 281ms/step - loss: 0.8482 - precision: 0.3649 - recall: 0.3103 - val_loss: 0.6154 - val_precision: 0.7778 - val_recall: 0.3182
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.8237 - precision: 0.4200 - recall: 0.4828 - val_loss: 0.5914 - val_precision: 0.7500 - val_recall: 0.4091
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.8137 - precision: 0.4444 - recall: 0.5057 - val_loss: 0.5651 - val_precision: 0.8000 - val_recall: 0.3636
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 0.7689 - precision: 0.4944 - recall: 0.5057 - val_loss: 0.5484 - val_precision: 0.7500 - val_recall: 0.4091
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - loss: 0.6688 - precision: 0.6040 - recall: 0.7011 - val_loss: 0.5264 - val_precision: 0.7500 - val_recall: 0.4091
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 0.6803 - precision: 0.5960 - recall: 0.6782 - val_loss: 0.5116 - val_precision: 0.7333 - val_recall: 0.5000
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - loss: 0.6490 - precision: 0.6087 - recall: 0.6437 - val_loss: 0.4959 - val_precision: 0.7647 - val_recall: 0.5909
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - loss: 0.6212 - precision: 0.6216 - recall: 0.7931 - val_loss: 0.4784 - val_precision: 0.8125 - val_recall: 0.5909
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - loss: 0.5833 - precision: 0.6989 - recall: 0.7471 - val_loss: 0.4571 - val_precision: 0.7857 - val_recall: 0.5000
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.5782 - precision: 0.6635 - recall: 0.7931 - val_loss: 0.4415 - val_precision: 0.8125 - val_recall: 0.5909
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - loss: 0.5609 - precision: 0.6429 - recall: 0.7241 - val_loss: 0.4339 - val_precision: 0.8235 - val_recall: 0.6364
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - loss: 0.4781 - precision: 0.7353 - recall: 0.8621 - val_loss: 0.4179 - val_precision: 0.8500 - val_recall: 0.7727
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - loss: 0.4997 - precision: 0.7113 - recall: 0.7931 - val_loss: 0.4019 - val_precision: 0.8636 - val_recall: 0.8636
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - loss: 0.4675 - precision: 0.7732 - recall: 0.8621 - val_loss: 0.3889 - val_precision: 0.9130 - val_recall: 0.9545
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 0.4531 - precision: 0.7742 - recall: 0.8276 - val_loss: 0.3743 - val_precision: 0.9130 - val_recall: 0.9545
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.4406 - precision: 0.7879 - recall: 0.8966 - val_loss: 0.3546 - val_precision: 0.9130 - val_recall: 0.9545
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.4141 - precision: 0.8046 - recall: 0.8046 - val_loss: 0.3505 - val_precision: 0.9130 - val_recall: 0.9545
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - loss: 0.4332 - precision: 0.7475 - recall: 0.8506 - val_loss: 0.3431 - val_precision: 0.8750 - val_recall: 0.9545
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - loss: 0.4145 - precision: 0.7849 - recall: 0.8391 - val_loss: 0.3421 - val_precision: 0.8400 - val_recall: 0.9545

# %%
import numpy as np
from sklearn.metrics import precision_recall_curve

y_scores = model.predict(img_test).ravel()

precision, recall, thresholds = precision_recall_curve(label_test, y_scores)

for p, r, t in zip(precision, recall, thresholds):
    if p >= 0.5:
        print(f"Threshold={t:.3f} | Precision={p:.3f} | Recall={r:.3f}")
        break
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step
# Threshold=0.314 | Precision=0.500 | Recall=0.955

# %% [markdown]
# Markdown
# # Model Validation and Visual Performance Analysis
# ### Qualitative Assessment of Image Expert Predictions via Integrated HTML Reporting
# ---

# %%
import os
import json
import random
import cv2
import base64
import numpy as np
import pandas as pd
from IPython.display import HTML

# 1. Setup & Load Model
EXPERT_MODEL_PATH = "models/tennis_stroke/image_expert_v1.h5"
JSON_PATH = "data/skeletons/skeletons.json"
IMAGES_DIR = "data/images_raw"
expert_model = tf.keras.models.load_model(EXPERT_MODEL_PATH)

with open(JSON_PATH, 'r') as f:
    labeled_data = [s for s in json.load(f) if s["label"] in ["backhand", "neutral"]]

# 2. Helper function to turn images into HTML
def image_to_base64_html(img_path):
    if not os.path.exists(img_path): return ""
    img = cv2.imread(img_path)
    img = cv2.resize(img, (150, 150)) # Thumbnail size for the table
    _, buffer = cv2.imencode('.jpg', img)
    img_str = base64.b64encode(buffer).decode()
    return f'<img src="data:image/jpeg;base64,{img_str}" width="150" height="150" />'

# 3. Pick 5 random test cases
samples = random.sample(labeled_data, 5)
results = []

for s in samples:
    path = os.path.join(IMAGES_DIR, s["image"])
    
    # Run Expert Prediction
    raw = cv2.imread(path)
    prep = cv2.resize(cv2.cvtColor(raw, cv2.COLOR_BGR2RGB), (224, 224))
    prep = (prep.astype(np.float32) / 127.5) - 1.0
    score = expert_model.predict(np.expand_dims(prep, axis=0), verbose=0)[0][0]
    
    pred_label = "BACKHAND" if score > 0.5 else "NEUTRAL"
    
    results.append({
        "Image Preview": image_to_base64_html(path),
        "Filename": s["image"],
        "Actual": s["label"].upper(),
        "Expert Pred": pred_label,
        "Conf Score": f"{score:.2%}",
        "Match": "✅" if pred_label == s["label"].upper() else "❌"
    })

# 4. Render the Table
df_results = pd.DataFrame(results)
HTML(df_results.to_html(escape=False))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image Preview</th>
#       <th>Filename</th>
#       <th>Actual</th>
#       <th>Expert Pred</th>
#       <th>Conf Score</th>
#       <th>Match</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..." width="150" height="150" /></td>
#       <td>alcaraz_frame_4648.jpg</td>
#       <td>NEUTRAL</td>
#       <td>BACKHAND</td>
#       <td>80.28%</td>
#       <td>❌</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..." width="150" height="150" /></td>
#       <td>alcaraz_frame_4410.jpg</td>
#       <td>NEUTRAL</td>
#       <td>BACKHAND</td>
#       <td>55.30%</td>
#       <td>❌</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..." width="150" height="150" /></td>
#       <td>f0c9cac8-fd94-11f0-9cb6-c288c7b5f717.jpg</td>
#       <td>NEUTRAL</td>
#       <td>NEUTRAL</td>
#       <td>13.02%</td>
#       <td>✅</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..." width="150" height="150" /></td>
#       <td>c6a50c62-fd94-11f0-9cb6-c288c7b5f717.jpg</td>
#       <td>BACKHAND</td>
#       <td>BACKHAND</td>
#       <td>94.99%</td>
#       <td>✅</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..." width="150" height="150" /></td>
#       <td>alcaraz_frame_3108.jpg</td>
#       <td>NEUTRAL</td>
#       <td>NEUTRAL</td>
#       <td>13.44%</td>
#       <td>✅</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Verified Video Extraction Pipeline
# ### High-Precision Backhand Detection via Skeleton Logic and CNN Validation Gate
# ---

# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import joblib
import os
from collections import deque
from mediapipe.tasks import python

# ----------------------------
# 1. Config & Paths
# ----------------------------
VIDEO_PATH = "test_video.mp4"
OUTPUT_FOLDER = "backhand_clips"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

MODEL_ASSET_PATH = "pose_landmarker_heavy.task"
KERAS_MODEL_PATH = "models/tennis_stroke/tennis_model_keras.h5"
ENCODER_PATH = "models/tennis_stroke/label_encoder_keras.pkl"
EXPERT_MODEL_PATH = "models/tennis_stroke/image_expert_v2.keras"

CNN_THRESHOLD = 0.31   # calibrated high-precision threshold

# ----------------------------
# 2. Load Models
# ----------------------------
print("📦 Loading models...")

keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
expert_model = tf.keras.models.load_model(EXPERT_MODEL_PATH)
expert_model.trainable = False  # IMPORTANT: inference mode

le = joblib.load(ENCODER_PATH)

print("✅ Models loaded\n")

# ----------------------------
# 3. MediaPipe & Video Setup
# ----------------------------
base_options = python.BaseOptions(model_asset_path=MODEL_ASSET_PATH)
options = mp.tasks.vision.PoseLandmarkerOptions(
    base_options=base_options,
    running_mode=mp.tasks.vision.RunningMode.VIDEO
)

cap = cv2.VideoCapture(VIDEO_PATH)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*"mp4v")

frame_buffer = deque(maxlen=fps)  # 1 second pre-buffer

# ----------------------------
# 4. Processing Loop
# ----------------------------
print("🎾 Starting backhand detection")
print("   Skeleton → candidate detection")
print("   CNN      → verification\n")

with mp.tasks.vision.PoseLandmarker.create_from_options(options) as landmarker:
    frame_count = 0
    clip_count = 0
    frames_to_record = 0
    current_writer = None
    cooldown_frames = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        timestamp_ms = int(1000 * frame_count / fps)
        frame_count += 1

        frame_buffer.append(frame.copy())

        if cooldown_frames > 0:
            cooldown_frames -= 1

        mp_image = mp.Image(
            image_format=mp.ImageFormat.SRGB,
            data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        )

        result = landmarker.detect_for_video(mp_image, timestamp_ms)

        is_backhand = False

        if result.pose_landmarks and cooldown_frames == 0:
            landmarks = result.pose_landmarks[0]

            # ----------------------------
            # Skeleton feature extraction
            # ----------------------------
            all_coords = np.array([(lm.x * width, lm.y * height) for lm in landmarks])

            mid_hip = (all_coords[23] + all_coords[24]) / 2
            shoulder_dist = np.linalg.norm(all_coords[11] - all_coords[12])
            if shoulder_dist < 1e-3:
                shoulder_dist = 1.0

            relevant_indices = [0, 2, 5, 11, 12, 13, 14, 15, 16, 23, 24]
            input_vector = []

            for idx in relevant_indices:
                norm_x = (all_coords[idx][0] - mid_hip[0]) / shoulder_dist
                norm_y = (all_coords[idx][1] - mid_hip[1]) / shoulder_dist
                input_vector.extend([norm_x, norm_y, landmarks[idx].visibility])

            input_data = np.array([input_vector], dtype=np.float32)

            # ----------------------------
            # Skeleton prediction
            # ----------------------------
            preds = keras_model.predict_on_batch(input_data)
            class_idx = np.argmax(preds[0])
            confidence = preds[0][class_idx]
            label = le.inverse_transform([class_idx])[0]

            print(
                f"[Frame {frame_count:05d} | {frame_count/fps:6.2f}s] "
                f"Skeleton → {label} ({confidence:.2f})"
            )

            # ----------------------------
            # CNN verification
            # ----------------------------
            if label.lower() == "backhand" and confidence > 0.85:
                cnn_img = cv2.resize(
                    cv2.cvtColor(frame, cv2.COLOR_BGR2RGB),
                    (224, 224)
                )
                cnn_img = (cnn_img.astype(np.float32) / 127.5) - 1.0
                cnn_img = np.expand_dims(cnn_img, axis=0)

                cnn_score = expert_model.predict(cnn_img, verbose=0)[0][0]

                print(f"           CNN → backhand score: {cnn_score:.2f}")

                if cnn_score > CNN_THRESHOLD:
                    is_backhand = True
                    print("           ✅ VERIFIED BACKHAND")
                else:
                    print("           ❌ REJECTED by CNN")

        # ----------------------------
        # Clip saving logic (UNCHANGED)
        # ----------------------------
        if is_backhand and frames_to_record <= 0:
            clip_count += 1
            clip_path = os.path.join(
                OUTPUT_FOLDER,
                f"backhand_{clip_count}.mp4"
            )

            current_writer = cv2.VideoWriter(
                clip_path, fourcc, fps, (width, height)
            )

            for buf_frame in frame_buffer:
                current_writer.write(buf_frame)

            frames_to_record = int(fps * 1.5)
            cooldown_frames = fps * 2

            print(f"\n🎬 Recording clip #{clip_count}\n")

        elif frames_to_record > 0:
            current_writer.write(frame)
            frames_to_record -= 1

            if frames_to_record == 0:
                current_writer.release()
                current_writer = None
                print(f"🟢 Finished clip #{clip_count}\n")

cap.release()
if current_writer:
    current_writer.release()

print(f"\n✅ Done! Total verified backhands: {clip_count}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📦 Loading models...
# ✅ Models loaded
#
# 🎾 Starting backhand detection
#    Skeleton → candidate detection
#    CNN      → verification
# I0000 00:00:1769768624.836465 30520891 gl_context.cc:407] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M1
# W0000 00:00:1769768624.890079 30520893 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769768624.981554 30520892 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# [Frame 00001 |   0.04s] Skeleton → neutral (1.00)
# [Frame 00002 |   0.09s] Skeleton → neutral (1.00)
# [Frame 00003 |   0.13s] Skeleton → neutral (1.00)
# [Frame 00004 |   0.17s] Skeleton → neutral (0.99)
# [Frame 00005 |   0.22s] Skeleton → neutral (0.98)
# [Frame 00006 |   0.26s] Skeleton → neutral (0.96)
# [Frame 00007 |   0.30s] Skeleton → neutral (0.95)
# [Frame 00008 |   0.35s] Skeleton → neutral (0.96)
# [Frame 00009 |   0.39s] Skeleton → neutral (0.93)
# [Frame 00010 |   0.43s] Skeleton → neutral (0.97)
# [Frame 00011 |   0.48s] Skeleton → neutral (1.00)
# [Frame 00012 |   0.52s] Skeleton → neutral (1.00)
# [Frame 00013 |   0.57s] Skeleton → neutral (1.00)
# [Frame 00014 |   0.61s] Skeleton → neutral (1.00)
# [Frame 00015 |   0.65s] Skeleton → neutral (1.00)
# [Frame 00016 |   0.70s] Skeleton → neutral (1.00)
# [Frame 00017 |   0.74s] Skeleton → neutral (0.94)
# [Frame 00018 |   0.78s] Skeleton → backhand (0.74)
# [Frame 00019 |   0.83s] Skeleton → neutral (0.86)
# [Frame 00020 |   0.87s] Skeleton → neutral (0.93)
# [Frame 00021 |   0.91s] Skeleton → neutral (0.97)
# [Frame 00022 |   0.96s] Skeleton → neutral (0.94)
# [Frame 00023 |   1.00s] Skeleton → neutral (0.91)
# [Frame 00024 |   1.04s] Skeleton → neutral (0.57)
# [Frame 00025 |   1.09s] Skeleton → backhand (0.81)
# [Frame 00026 |   1.13s] Skeleton → backhand (0.87)
#            CNN → backhand score: 0.42
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #1
#
# 🟢 Finished clip #1
#
# [Frame 00072 |   3.13s] Skeleton → neutral (1.00)
# [Frame 00073 |   3.17s] Skeleton → neutral (0.99)
# [Frame 00074 |   3.22s] Skeleton → neutral (0.99)
# [Frame 00075 |   3.26s] Skeleton → neutral (1.00)
# [Frame 00076 |   3.30s] Skeleton → neutral (1.00)
# [Frame 00077 |   3.35s] Skeleton → neutral (1.00)
# [Frame 00078 |   3.39s] Skeleton → neutral (1.00)
# [Frame 00079 |   3.43s] Skeleton → neutral (1.00)
# [Frame 00080 |   3.48s] Skeleton → neutral (1.00)
# [Frame 00081 |   3.52s] Skeleton → neutral (1.00)
# [Frame 00082 |   3.57s] Skeleton → neutral (1.00)
# [Frame 00083 |   3.61s] Skeleton → neutral (1.00)
# [Frame 00084 |   3.65s] Skeleton → neutral (0.98)
# [Frame 00085 |   3.70s] Skeleton → neutral (0.91)
# [Frame 00086 |   3.74s] Skeleton → neutral (0.87)
# [Frame 00087 |   3.78s] Skeleton → neutral (0.87)
# [Frame 00137 |   5.96s] Skeleton → neutral (0.97)
# [Frame 00138 |   6.00s] Skeleton → neutral (0.97)
# [Frame 00139 |   6.04s] Skeleton → neutral (0.96)
# [Frame 00140 |   6.09s] Skeleton → neutral (0.95)
# [Frame 00141 |   6.13s] Skeleton → neutral (0.88)
# [Frame 00142 |   6.17s] Skeleton → neutral (0.73)
# [Frame 00143 |   6.22s] Skeleton → backhand (0.74)
# [Frame 00144 |   6.26s] Skeleton → backhand (0.96)
#            CNN → backhand score: 0.50
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #2
#
# 🟢 Finished clip #2
#
# [Frame 00190 |   8.26s] Skeleton → neutral (1.00)
# [Frame 00191 |   8.30s] Skeleton → neutral (1.00)
# [Frame 00192 |   8.35s] Skeleton → neutral (1.00)
# [Frame 00193 |   8.39s] Skeleton → neutral (1.00)
# [Frame 00194 |   8.43s] Skeleton → neutral (1.00)
# [Frame 00195 |   8.48s] Skeleton → neutral (1.00)
# [Frame 00196 |   8.52s] Skeleton → neutral (1.00)
# [Frame 00197 |   8.57s] Skeleton → neutral (1.00)
# [Frame 00198 |   8.61s] Skeleton → neutral (1.00)
# [Frame 00199 |   8.65s] Skeleton → neutral (1.00)
# [Frame 00200 |   8.70s] Skeleton → neutral (1.00)
# [Frame 00201 |   8.74s] Skeleton → neutral (1.00)
# [Frame 00202 |   8.78s] Skeleton → neutral (1.00)
# [Frame 00203 |   8.83s] Skeleton → neutral (1.00)
# [Frame 00204 |   8.87s] Skeleton → neutral (0.98)
# [Frame 00205 |   8.91s] Skeleton → neutral (0.99)
# [Frame 00206 |   8.96s] Skeleton → neutral (0.97)
# [Frame 00207 |   9.00s] Skeleton → neutral (0.95)
# [Frame 00208 |   9.04s] Skeleton → neutral (0.92)
# [Frame 00209 |   9.09s] Skeleton → neutral (0.86)
# [Frame 00210 |   9.13s] Skeleton → backhand (0.70)
# [Frame 00211 |   9.17s] Skeleton → backhand (0.91)
#            CNN → backhand score: 0.57
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #3
#
# 🟢 Finished clip #3
#
# [Frame 00257 |  11.17s] Skeleton → neutral (1.00)
# [Frame 00258 |  11.22s] Skeleton → neutral (1.00)
# [Frame 00259 |  11.26s] Skeleton → neutral (1.00)
# [Frame 00260 |  11.30s] Skeleton → neutral (1.00)
# [Frame 00261 |  11.35s] Skeleton → neutral (0.99)
# [Frame 00262 |  11.39s] Skeleton → neutral (0.98)
# [Frame 00263 |  11.43s] Skeleton → neutral (0.96)
# [Frame 00264 |  11.48s] Skeleton → neutral (0.94)
# [Frame 00265 |  11.52s] Skeleton → neutral (0.95)
# [Frame 00266 |  11.57s] Skeleton → neutral (0.96)
# [Frame 00267 |  11.61s] Skeleton → neutral (0.97)
# [Frame 00268 |  11.65s] Skeleton → neutral (0.98)
# [Frame 00269 |  11.70s] Skeleton → neutral (0.98)
# [Frame 00270 |  11.74s] Skeleton → neutral (1.00)
# [Frame 00271 |  11.78s] Skeleton → neutral (1.00)
# [Frame 00272 |  11.83s] Skeleton → neutral (1.00)
# [Frame 00273 |  11.87s] Skeleton → neutral (1.00)
# [Frame 00368 |  16.00s] Skeleton → neutral (1.00)
# [Frame 00369 |  16.04s] Skeleton → neutral (1.00)
# [Frame 00370 |  16.09s] Skeleton → neutral (1.00)
# [Frame 00371 |  16.13s] Skeleton → neutral (1.00)
# [Frame 00372 |  16.17s] Skeleton → neutral (0.99)
# [Frame 00373 |  16.22s] Skeleton → neutral (1.00)
# [Frame 00374 |  16.26s] Skeleton → neutral (1.00)
# [Frame 00375 |  16.30s] Skeleton → neutral (1.00)
# [Frame 00376 |  16.35s] Skeleton → neutral (1.00)
# [Frame 00377 |  16.39s] Skeleton → neutral (1.00)
# [Frame 00378 |  16.43s] Skeleton → neutral (1.00)
# [Frame 00379 |  16.48s] Skeleton → neutral (1.00)
# [Frame 00380 |  16.52s] Skeleton → neutral (1.00)
# [Frame 00381 |  16.57s] Skeleton → neutral (0.89)
# [Frame 00382 |  16.61s] Skeleton → backhand (0.66)
# [Frame 00383 |  16.65s] Skeleton → neutral (0.94)
# [Frame 00384 |  16.70s] Skeleton → neutral (0.98)
# [Frame 00385 |  16.74s] Skeleton → neutral (0.98)
# [Frame 00386 |  16.78s] Skeleton → neutral (0.97)
# [Frame 00387 |  16.83s] Skeleton → neutral (0.91)
# [Frame 00388 |  16.87s] Skeleton → neutral (0.79)
# [Frame 00389 |  16.91s] Skeleton → neutral (0.65)
# [Frame 00390 |  16.96s] Skeleton → backhand (0.63)
# [Frame 00391 |  17.00s] Skeleton → backhand (0.84)
# [Frame 00392 |  17.04s] Skeleton → backhand (0.87)
#            CNN → backhand score: 0.49
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #5
#
# 🟢 Finished clip #5
#
# [Frame 00438 |  19.04s] Skeleton → neutral (0.94)
# [Frame 00439 |  19.09s] Skeleton → neutral (0.94)
# [Frame 00440 |  19.13s] Skeleton → neutral (1.00)
# [Frame 00441 |  19.17s] Skeleton → neutral (1.00)
# [Frame 00442 |  19.22s] Skeleton → neutral (1.00)
# [Frame 00443 |  19.26s] Skeleton → neutral (1.00)
# [Frame 00444 |  19.30s] Skeleton → neutral (1.00)
# [Frame 00445 |  19.35s] Skeleton → neutral (1.00)
# [Frame 00446 |  19.39s] Skeleton → neutral (1.00)
# [Frame 00447 |  19.43s] Skeleton → neutral (1.00)
# [Frame 00448 |  19.48s] Skeleton → neutral (1.00)
# [Frame 00449 |  19.52s] Skeleton → neutral (0.83)
# [Frame 00450 |  19.57s] Skeleton → neutral (0.62)
# [Frame 00451 |  19.61s] Skeleton → neutral (0.88)
# [Frame 00452 |  19.65s] Skeleton → neutral (0.94)
# [Frame 00453 |  19.70s] Skeleton → neutral (0.91)
# [Frame 00454 |  19.74s] Skeleton → neutral (0.64)
# [Frame 00455 |  19.78s] Skeleton → backhand (0.61)
# [Frame 00456 |  19.83s] Skeleton → backhand (0.82)
# [Frame 00457 |  19.87s] Skeleton → backhand (0.88)
#            CNN → backhand score: 0.52
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #6
#
# 🟢 Finished clip #6
#
# [Frame 00503 |  21.87s] Skeleton → backhand (1.00)
#            CNN → backhand score: 0.50
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip
# [Frame 00686 |  29.83s] Skeleton → neutral (1.00)
# [Frame 00687 |  29.87s] Skeleton → neutral (1.00)
# [Frame 00688 |  29.91s] Skeleton → neutral (1.00)
# [Frame 00689 |  29.96s] Skeleton → neutral (1.00)
# [Frame 00690 |  30.00s] Skeleton → neutral (1.00)
# [Frame 00691 |  30.04s] Skeleton → neutral (0.99)
# [Frame 00692 |  30.09s] Skeleton → neutral (0.98)
# [Frame 00693 |  30.13s] Skeleton → neutral (0.97)
# [Frame 00694 |  30.17s] Skeleton → neutral (0.95)
# [Frame 00695 |  30.22s] Skeleton → neutral (0.84)
# [Frame 00696 |  30.26s] Skeleton → neutral (0.53)
# [Frame 00697 |  30.30s] Skeleton → backhand (0.66)
# [Frame 00698 |  30.35s] Skeleton → backhand (0.94)
#            CNN → backhand score: 0.48
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #10
#
# 🟢 Finished clip #10
#
# [Frame 00744 |  32.35s] Skeleton → neutral (1.00)
# [Frame 00745 |  32.39s] Skeleton → neutral (1.00)
# [Frame 00746 |  32.43s] Skeleton → neutral (1.00)
# [Frame 00747 |  32.48s] Skeleton → neutral (1.00)
# [Frame 00748 |  32.52s] Skeleton → neutral (1.00)
# [Frame 00749 |  32.57s] Skeleton → neutral (1.00)
# [Frame 00750 |  32.61s] Skeleton → neutral (1.00)
# [Frame 00751 |  32.65s] Skeleton → neutral (1.00)
# [Frame 00752 |  32.70s] Skeleton → neutral (1.00)
# [Frame 00753 |  32.74s] Skeleton → neutral (1.00)
# [Frame 00754 |  32.78s] Skeleton → neutral (1.00)
# [Frame 00755 |  32.83s] Skeleton → neutral (0.99)
# [Frame 00756 |  32.87s] Skeleton → neutral (0.98)
# [Frame 00757 |  32.91s] Skeleton → neutral (0.97)
# [Frame 00758 |  32.96s] Skeleton → neutral (0.95)
# [Frame 00759 |  33.00s] Skeleton → neutral (0.84)
# [Frame 00760 |  33.04s] Skeleton → neutral (0.62)
# [Frame 00761 |  33.09s] Skeleton → backhand (0.86)
#            CNN → backhand score: 0.58
#            ✅ VERIFIED BACKHAND
#
# 🎬 Recording clip #11
#
#
# ✅ Done! Total verified backhands: 11

# %% [markdown]
# # Creating data set for rejector MLP

# %%
import json
import numpy as np
import tensorflow as tf
import joblib
from sklearn.model_selection import train_test_split

# ----------------------------
# Paths
# ----------------------------
SKELETONS_PATH = "data/skeletons/skeletons.json"
MAIN_MODEL_PATH = "models/tennis_stroke/tennis_model_keras"
ENCODER_PATH = "models/tennis_stroke/label_encoder_keras.pkl"

# ----------------------------
# Load models
# ----------------------------
main_model = tf.keras.models.load_model(MAIN_MODEL_PATH)
le = joblib.load(ENCODER_PATH)

# ----------------------------
# Build rejector dataset
# ----------------------------
X = []
y = []

with open(SKELETONS_PATH) as f:
    data = json.load(f)

for sample in data:
    if sample["label"] not in ["backhand", "neutral"]:
        continue

    joints = np.array(sample["joints_norm"]).flatten()

    # Run main model
    preds = main_model.predict(
        joints.reshape(1, -1),
        verbose=0
    )
    pred_label = le.inverse_transform([np.argmax(preds[0])])[0]

    # Keep:
    # - true backhands
    # - forehands that fool the main model
    if sample["label"] == "backhand":
        X.append(joints)
        y.append(1)
    elif sample["label"] == "neutral":
        X.append(joints)
        y.append(0)

X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.int32)

print(f"Rejector dataset size: {len(X)}")
print(f"Backhands: {np.sum(y)} | Forehands: {len(y) - np.sum(y)}")

# Train / val split
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)
# Out:
# Rejector dataset size: 353
# Backhands: 109 | Forehands: 244

# %% [markdown]
# # Rejector MLP strict

# %%
def build_rejector_mlp(input_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_dim,)),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(32, activation="relu"),
        tf.keras.layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
rejector = build_rejector_mlp(X_train.shape[1])

history = rejector.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=40,
    batch_size=32,
    class_weight={0: 1.0, 1: 1.5},  # bias toward keeping backhands
    verbose=1
)

REJECTOR_DIR = "models/tennis_stroke/skeleton_rejector"
rejector.save(REJECTOR_DIR, save_format="tf")  # SavedModel format

print(f"✅ Rejector model saved at {REJECTOR_DIR}")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/40
# 9/9 [==============================] - 0s 9ms/step - loss: 0.7830 - accuracy: 0.4716 - val_loss: 0.6149 - val_accuracy: 0.7465
# Epoch 2/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.7553 - val_loss: 0.5236 - val_accuracy: 0.9155
# Epoch 3/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8582 - val_loss: 0.4803 - val_accuracy: 0.9014
# Epoch 4/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.9184 - val_loss: 0.4539 - val_accuracy: 0.8873
# Epoch 5/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.9326 - val_loss: 0.4331 - val_accuracy: 0.8592
# Epoch 6/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.9291 - val_loss: 0.4097 - val_accuracy: 0.8873
# Epoch 7/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9539 - val_loss: 0.3883 - val_accuracy: 0.9155
# Epoch 8/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9468 - val_loss: 0.3654 - val_accuracy: 0.9155
# Epoch 9/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9539 - val_loss: 0.3501 - val_accuracy: 0.9155
# Epoch 10/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1841 - accuracy: 0.9610 - val_loss: 0.3314 - val_accuracy: 0.9155
# Epoch 11/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9539 - val_loss: 0.3146 - val_accuracy: 0.9296
# Epoch 12/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1673 - accuracy: 0.9468 - val_loss: 0.3020 - val_accuracy: 0.9577
# Epoch 13/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1624 - accuracy: 0.9610 - val_loss: 0.2960 - val_accuracy: 0.9437
# Epoch 14/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9504 - val_loss: 0.2791 - val_accuracy: 0.9577
# Epoch 15/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9539 - val_loss: 0.2566 - val_accuracy: 0.9577
# Epoch 16/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9610 - val_loss: 0.2401 - val_accuracy: 0.9437
# Epoch 17/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9539 - val_loss: 0.2318 - val_accuracy: 0.9577
# Epoch 18/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1434 - accuracy: 0.9504 - val_loss: 0.2269 - val_accuracy: 0.9437
# Epoch 19/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9539 - val_loss: 0.2204 - val_accuracy: 0.9437
# Epoch 20/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1282 - accuracy: 0.9681 - val_loss: 0.2147 - val_accuracy: 0.9437
# Epoch 21/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9716 - val_loss: 0.2071 - val_accuracy: 0.9437
# Epoch 22/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9716 - val_loss: 0.2041 - val_accuracy: 0.9437
# Epoch 23/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9716 - val_loss: 0.2075 - val_accuracy: 0.9577
# Epoch 24/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9752 - val_loss: 0.1936 - val_accuracy: 0.9437
# Epoch 25/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9645 - val_loss: 0.1960 - val_accuracy: 0.9577
# Epoch 26/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.9681 - val_loss: 0.2016 - val_accuracy: 0.9577
# Epoch 27/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9681 - val_loss: 0.1935 - val_accuracy: 0.9577
# Epoch 28/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9681 - val_loss: 0.2009 - val_accuracy: 0.9577
# Epoch 29/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9645 - val_loss: 0.1903 - val_accuracy: 0.9577
# Epoch 30/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9716 - val_loss: 0.1829 - val_accuracy: 0.9437
# Epoch 31/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9681 - val_loss: 0.1956 - val_accuracy: 0.9577
# Epoch 32/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9645 - val_loss: 0.2094 - val_accuracy: 0.9437
# Epoch 33/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9787 - val_loss: 0.1911 - val_accuracy: 0.9577
# Epoch 34/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9787 - val_loss: 0.1798 - val_accuracy: 0.9577
# Epoch 35/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9681 - val_loss: 0.1837 - val_accuracy: 0.9577
# Epoch 36/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9787 - val_loss: 0.2084 - val_accuracy: 0.9437
# Epoch 37/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9681 - val_loss: 0.2029 - val_accuracy: 0.9437
# Epoch 38/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9858 - val_loss: 0.1922 - val_accuracy: 0.9577
# Epoch 39/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9787 - val_loss: 0.1970 - val_accuracy: 0.9437
# Epoch 40/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9610 - val_loss: 0.1867 - val_accuracy: 0.9577
# INFO:tensorflow:Assets written to: models/tennis_stroke/skeleton_rejector/assets
# INFO:tensorflow:Assets written to: models/tennis_stroke/skeleton_rejector/assets
# ✅ Rejector model saved at models/tennis_stroke/skeleton_rejector

# %% [markdown]
# # Full script with rejector MLP

# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import joblib
import os
from collections import deque
from mediapipe.tasks import python

# ----------------------------
# 1. Config & Paths
# ----------------------------
VIDEO_PATH = "r.mp4"
OUTPUT_FOLDER = "backhand_clips"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

MODEL_ASSET_PATH = "pose_landmarker_heavy.task"
KERAS_MODEL_PATH = "models/tennis_stroke/tennis_model_keras"
ENCODER_PATH = "models/tennis_stroke/label_encoder_keras.pkl"
REJECTOR_PATH = "models/tennis_stroke/skeleton_rejector"
rejector = tf.keras.models.load_model(REJECTOR_PATH)

CNN_THRESHOLD = 0.31   # calibrated high-precision threshold

# ----------------------------
# 2. Load Models
# ----------------------------
print("📦 Loading models...")

keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
expert_model = tf.keras.models.load_model(REJECTOR_PATH)
expert_model.trainable = False  # IMPORTANT: inference mode

le = joblib.load(ENCODER_PATH)

print("✅ Models loaded\n")

# ----------------------------
# 3. MediaPipe & Video Setup
# ----------------------------
base_options = python.BaseOptions(model_asset_path=MODEL_ASSET_PATH)
options = mp.tasks.vision.PoseLandmarkerOptions(
    base_options=base_options,
    running_mode=mp.tasks.vision.RunningMode.VIDEO
)

cap = cv2.VideoCapture(VIDEO_PATH)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*"mp4v")

frame_buffer = deque(maxlen=fps)  # 1 second pre-buffer

# ----------------------------
# 4. Processing Loop
# ----------------------------
print("🎾 Starting backhand detection")
print("   Skeleton → candidate detection")
print("   CNN      → verification\n")

with mp.tasks.vision.PoseLandmarker.create_from_options(options) as landmarker:
    frame_count = 0
    clip_count = 0
    frames_to_record = 0
    current_writer = None
    cooldown_frames = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        timestamp_ms = int(1000 * frame_count / fps)
        frame_count += 1

        frame_buffer.append(frame.copy())

        if cooldown_frames > 0:
            cooldown_frames -= 1

        mp_image = mp.Image(
            image_format=mp.ImageFormat.SRGB,
            data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        )

        result = landmarker.detect_for_video(mp_image, timestamp_ms)

        is_backhand = False

        if result.pose_landmarks and cooldown_frames == 0:
            landmarks = result.pose_landmarks[0]

            # ----------------------------
            # Skeleton feature extraction
            # ----------------------------
            all_coords = np.array([(lm.x * width, lm.y * height) for lm in landmarks])

            mid_hip = (all_coords[23] + all_coords[24]) / 2
            shoulder_dist = np.linalg.norm(all_coords[11] - all_coords[12])
            if shoulder_dist < 1e-3:
                shoulder_dist = 1.0

            relevant_indices = [0, 2, 5, 11, 12, 13, 14, 15, 16, 23, 24]
            input_vector = []

            for idx in relevant_indices:
                norm_x = (all_coords[idx][0] - mid_hip[0]) / shoulder_dist
                norm_y = (all_coords[idx][1] - mid_hip[1]) / shoulder_dist
                input_vector.extend([norm_x, norm_y, landmarks[idx].visibility])

            input_data = np.array([input_vector], dtype=np.float32)

            # ----------------------------
            # Skeleton prediction
            # ----------------------------
            preds = keras_model.predict_on_batch(input_data)
            class_idx = np.argmax(preds[0])
            confidence = preds[0][class_idx]
            label = le.inverse_transform([class_idx])[0]

            print(
                f"[Frame {frame_count:05d} | {frame_count/fps:6.2f}s] "
                f"Skeleton → {label} ({confidence:.2f})"
            )

            # ----------------------------
            # CNN verification
            # ----------------------------
            if label.lower() == "backhand" and confidence > 0.85 and cooldown_frames == 0:
                rejector_score = rejector.predict(
                    input_data,
                    verbose=0
                )[0][0]
            
                print(
                    f"           Rejector → backhand prob: {rejector_score:.2f}"
                )
            
                if rejector_score > 0.9:
                    is_backhand = True
                    print("           ✅ ACCEPTED by rejector")
                else:
                    print("           ❌ REJECTED as forehand")


        # ----------------------------
        # Clip saving logic (UNCHANGED)
        # ----------------------------
        if is_backhand and frames_to_record <= 0:
            clip_count += 1
            clip_path = os.path.join(
                OUTPUT_FOLDER,
                f"backhand_{clip_count}.mp4"
            )

            current_writer = cv2.VideoWriter(
                clip_path, fourcc, fps, (width, height)
            )

            for buf_frame in frame_buffer:
                current_writer.write(buf_frame)

            frames_to_record = int(fps * 1.5)
            cooldown_frames = fps * 2

            print(f"\n🎬 Recording clip #{clip_count}\n")

        elif frames_to_record > 0:
            current_writer.write(frame)
            frames_to_record -= 1

            if frames_to_record == 0:
                current_writer.release()
                current_writer = None
                print(f"🟢 Finished clip #{clip_count}\n")

cap.release()
if current_writer:
    current_writer.release()

print(f"\n✅ Done! Total verified backhands: {clip_count}")
# Out:
# 📦 Loading models...
# ✅ Models loaded
#
# 🎾 Starting backhand detection
#    Skeleton → candidate detection
#    CNN      → verification
# I0000 00:00:1770201713.346939       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M1
# [Frame 00001 |   0.03s] Skeleton → neutral (1.00)
# [Frame 00002 |   0.07s] Skeleton → neutral (1.00)
# [Frame 00003 |   0.10s] Skeleton → neutral (1.00)
# [Frame 00004 |   0.13s] Skeleton → neutral (1.00)
# [Frame 00005 |   0.17s] Skeleton → neutral (1.00)
# [Frame 00006 |   0.20s] Skeleton → neutral (1.00)
# [Frame 00057 |   1.90s] Skeleton → neutral (0.70)
# [Frame 00058 |   1.93s] Skeleton → neutral (0.67)
# [Frame 00059 |   1.97s] Skeleton → neutral (0.64)
# [Frame 00060 |   2.00s] Skeleton → neutral (0.52)
# [Frame 00061 |   2.03s] Skeleton → neutral (0.65)
# [Frame 00062 |   2.07s] Skeleton → neutral (0.73)
# [Frame 00063 |   2.10s] Skeleton → backhand (0.94)
#            Rejector → backhand prob: 0.19
#            ❌ REJECTED as forehand
# [Frame 00064 |   2.13s] Skeleton → backhand (0.99)
#            Rejector → backhand prob: 0.45
#            ❌ REJECTED as forehand
# [Frame 00065 |   2.17s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.32
#            ❌ REJECTED as forehand
# [Frame 00066 |   2.20s] Skeleton → backhand (0.50)
# [Frame 00067 |   2.23s] Skeleton → backhand (0.83)
# [Frame 00068 |   2.27s] Skeleton → neutral (0.75)
# [Frame 00069 |   2.30s] Skeleton → backhand (0.54)
# [Frame 00070 |   2.33s] Skeleton → backhand (0.64)
# [Frame 00071 |   2.37s] Skeleton → neutral (0.51)
# [Frame 00072 |   2.40s] Skeleton → neutral (0.55)
# [Frame 00073 |   2.43s] Skeleton → neutral (0.59)
# [Frame 00074 |   2.47s] Skeleton → neutral (0.73)
# [Frame 00075 |   2.50s] Skeleton → neutral (0.86)
# [Frame 00076 |   2.53s] Skeleton → neutral (0.91)
# [Frame 00077 |   2.57s] Skeleton → neutral (0.89)
# [Frame 00078 |   2.60s] Skeleton → neutral (0.90)
# [Frame 00079 |   2.63s] Skeleton → neutral (0.90)
# [Frame 00080 |   2.67s] Skeleton → neutral (0.91)
# [Frame 00081 |   2.70s] Skeleton → neutral (0.92)
# [Frame 00082 |   2.73s] Skeleton → neutral (0.93)
# [Frame 00083 |   2.77s] Skeleton → neutral (0.94)
# [Frame 00084 |   2.80s] Skeleton → neutral (0.94)
# [Frame 00085 |   2.83s] Skeleton → neutral (0.95)
# [Frame 00086 |   2.87s] Skeleton → neutral (0.94)
# [Frame 00087 |   2.90s] Skeleton → neutral (0.94)
# [Frame 00088 |   2.93s] Skeleton → neutral (0.96)
# [Frame 00089 |   2.97s] Skeleton → neutral (0.99)
# [Frame 00090 |   3.00s] Skeleton → neutral (0.99)
# [Frame 00091 |   3.03s] Skeleton → neutral (1.00)
# [Frame 00092 |   3.07s] Skeleton → neutral (1.00)
# [Frame 00093 |   3.10s] Skeleton → neutral (1.00)
# [Frame 00094 |   3.13s] Skeleton → neutral (1.00)
# [Frame 00095 |   3.17s] Skeleton → neutral (1.00)
# [Frame 00096 |   3.20s] Skeleton → neutral (1.00)
# [Frame 00097 |   3.23s] Skeleton → neutral (1.00)
# [Frame 00098 |   3.27s] Skeleton → neutral (1.00)
# [Frame 00099 |   3.30s] Skeleton → neutral (1.00)
# [Frame 00100 |   3.33s] Skeleton → neutral (1.00)
# [Frame 00101 |   3.37s] Skeleton → neutral (1.00)
# [Frame 00102 |   3.40s] Skeleton → neutral (1.00)
# [Frame 00103 |   3.43s] Skeleton → neutral (1.00)
# [Frame 00104 |   3.47s] Skeleton → neutral (0.93)
# [Frame 00105 |   3.50s] Skeleton → neutral (0.95)
# [Frame 00106 |   3.53s] Skeleton → neutral (0.93)
# [Frame 00107 |   3.57s] Skeleton → neutral (0.93)
# [Frame 00108 |   3.60s] Skeleton → neutral (0.93)
# [Frame 00109 |   3.63s] Skeleton → neutral (0.94)
# [Frame 00110 |   3.67s] Skeleton → neutral (0.87)
# [Frame 00111 |   3.70s] Skeleton → neutral (0.76)
# [Frame 00112 |   3.73s] Skeleton → backhand (0.66)
# [Frame 00113 |   3.77s] Skeleton → backhand (0.93)
#            Rejector → backhand prob: 0.85
#            ❌ REJECTED as forehand
# [Frame 00114 |   3.80s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.91
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #1
#
# 🟢 Finished clip #1
#
# [Frame 00174 |   5.80s] Skeleton → neutral (1.00)
# [Frame 00175 |   5.83s] Skeleton → neutral (1.00)
# [Frame 00176 |   5.87s] Skeleton → neutral (1.00)
# [Frame 00177 |   5.90s] Skeleton → neutral (1.00)
# [Frame 00178 |   5.93s] Skeleton → neutral (1.00)
# [Frame 00179 |   5.97s] Skeleton → neutral (0.95)
# [Frame 00180 |   6.00s] Skeleton → neutral (0.96)
# [Frame 00181 |   6.03s] Skeleton → neutral (0.93)
# [Frame 00182 |   6.07s] Skeleton → neutral (0.93)
# [Frame 00183 |   6.10s] Skeleton → neutral (0.93)
# [Frame 00184 |   6.13s] Skeleton → neutral (0.95)
# [Frame 00185 |   6.17s] Skeleton → neutral (0.95)
# [Frame 00186 |   6.20s] Skeleton → neutral (0.95)
# [Frame 00187 |   6.23s] Skeleton → neutral (0.88)
# [Frame 00188 |   6.27s] Skeleton → neutral (0.76)
# [Frame 00189 |   6.30s] Skeleton → backhand (0.64)
# [Frame 00190 |   6.33s] Skeleton → backhand (0.90)
#            Rejector → backhand prob: 0.82
#            ❌ REJECTED as forehand
# [Frame 00191 |   6.37s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.92
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #2
#
# 🟢 Finished clip #2
#
# [Frame 00251 |   8.37s] Skeleton → neutral (1.00)
# [Frame 00252 |   8.40s] Skeleton → neutral (1.00)
# [Frame 00253 |   8.43s] Skeleton → neutral (1.00)
# [Frame 00254 |   8.47s] Skeleton → neutral (1.00)
# [Frame 00255 |   8.50s] Skeleton → neutral (1.00)
# [Frame 00256 |   8.53s] Skeleton → neutral (1.00)
# [Frame 00257 |   8.57s] Skeleton → neutral (1.00)
# [Frame 00258 |   8.60s] Skeleton → neutral (1.00)
# [Frame 00259 |   8.63s] Skeleton → neutral (1.00)
# [Frame 00260 |   8.67s] Skeleton → neutral (1.00)
# [Frame 00261 |   8.70s] Skeleton → neutral (1.00)
# [Frame 00262 |   8.73s] Skeleton → neutral (0.99)
# [Frame 00263 |   8.77s] Skeleton → neutral (0.98)
# [Frame 00264 |   8.80s] Skeleton → neutral (0.92)
# [Frame 00265 |   8.83s] Skeleton → neutral (0.96)
# [Frame 00266 |   8.87s] Skeleton → neutral (0.99)
# [Frame 00267 |   8.90s] Skeleton → neutral (0.99)
# [Frame 00268 |   8.93s] Skeleton → neutral (1.00)
# [Frame 00269 |   8.97s] Skeleton → neutral (1.00)
# [Frame 00270 |   9.00s] Skeleton → neutral (1.00)
# [Frame 00427 |  14.23s] Skeleton → neutral (1.00)
# [Frame 00428 |  14.27s] Skeleton → neutral (1.00)
# [Frame 00429 |  14.30s] Skeleton → neutral (1.00)
# [Frame 00430 |  14.33s] Skeleton → neutral (1.00)
# [Frame 00431 |  14.37s] Skeleton → neutral (1.00)
# [Frame 00432 |  14.40s] Skeleton → neutral (1.00)
# [Frame 00433 |  14.43s] Skeleton → neutral (1.00)
# [Frame 00434 |  14.47s] Skeleton → neutral (1.00)
# [Frame 00435 |  14.50s] Skeleton → neutral (1.00)
# [Frame 00436 |  14.53s] Skeleton → neutral (1.00)
# [Frame 00437 |  14.57s] Skeleton → neutral (1.00)
# [Frame 00438 |  14.60s] Skeleton → neutral (0.99)
# [Frame 00439 |  14.63s] Skeleton → neutral (0.97)
# [Frame 00440 |  14.67s] Skeleton → neutral (0.96)
# [Frame 00441 |  14.70s] Skeleton → neutral (0.92)
# [Frame 00442 |  14.73s] Skeleton → neutral (0.96)
# [Frame 00443 |  14.77s] Skeleton → neutral (0.99)
# [Frame 00444 |  14.80s] Skeleton → neutral (1.00)
# [Frame 00445 |  14.83s] Skeleton → neutral (1.00)
# [Frame 00446 |  14.87s] Skeleton → neutral (1.00)
# [Frame 00447 |  14.90s] Skeleton → neutral (1.00)
# [Frame 00448 |  14.93s] Skeleton → neutral (1.00)
# [Frame 00449 |  14.97s] Skeleton → neutral (1.00)
# [Frame 00450 |  15.00s] Skeleton → neutral (1.00)
# [Frame 00451 |  15.03s] Skeleton → neutral (0.94)
# [Frame 00452 |  15.07s] Skeleton → neutral (0.89)
# [Frame 00453 |  15.10s] Skeleton → neutral (0.99)
# [Frame 00454 |  15.13s] Skeleton → neutral (1.00)
# [Frame 00455 |  15.17s] Skeleton → neutral (0.98)
# [Frame 00456 |  15.20s] Skeleton → neutral (1.00)
# [Frame 00457 |  15.23s] Skeleton → neutral (0.99)
# [Frame 00458 |  15.27s] Skeleton → backhand (0.90)
#            Rejector → backhand prob: 0.18
#            ❌ REJECTED as forehand
# [Frame 00459 |  15.30s] Skeleton → neutral (0.89)
# [Frame 00460 |  15.33s] Skeleton → backhand (0.96)
#            Rejector → backhand prob: 0.18
#            ❌ REJECTED as forehand
# [Frame 00461 |  15.37s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.41
#            ❌ REJECTED as forehand
# [Frame 00462 |  15.40s] Skeleton → backhand (0.78)
# [Frame 00463 |  15.43s] Skeleton → neutral (0.75)
# [Frame 00464 |  15.47s] Skeleton → backhand (0.83)
# [Frame 00465 |  15.50s] Skeleton → backhand (0.85)
#            Rejector → backhand prob: 0.36
#            ❌ REJECTED as forehand
# [Frame 00466 |  15.53s] Skeleton → backhand (0.69)
# [Frame 00467 |  15.57s] Skeleton → neutral (0.80)
# [Frame 00468 |  15.60s] Skeleton → neutral (0.92)
# [Frame 00469 |  15.63s] Skeleton → neutral (0.88)
# [Frame 00470 |  15.67s] Skeleton → neutral (0.92)
# [Frame 00471 |  15.70s] Skeleton → neutral (0.51)
# [Frame 00472 |  15.73s] Skeleton → neutral (0.67)
# [Frame 00473 |  15.77s] Skeleton → backhand (0.69)
# [Frame 00474 |  15.80s] Skeleton → neutral (0.51)
# [Frame 00475 |  15.83s] Skeleton → neutral (0.54)
# [Frame 00476 |  15.87s] Skeleton → neutral (0.88)
# [Frame 00477 |  15.90s] Skeleton → neutral (0.96)
# [Frame 00478 |  15.93s] Skeleton → neutral (0.98)
# [Frame 00479 |  15.97s] Skeleton → neutral (0.99)
# [Frame 00480 |  16.00s] Skeleton → neutral (1.00)
# [Frame 00481 |  16.03s] Skeleton → neutral (1.00)
# [Frame 00482 |  16.07s] Skeleton → neutral (1.00)
# [Frame 00483 |  16.10s] Skeleton → neutral (1.00)
# [Frame 00484 |  16.13s] Skeleton → neutral (1.00)
# [Frame 00485 |  16.17s] Skeleton → neutral (0.99)
# [Frame 00486 |  16.20s] Skeleton → neutral (0.94)
# [Frame 00487 |  16.23s] Skeleton → neutral (1.00)
# [Frame 00488 |  16.27s] Skeleton → neutral (1.00)
# [Frame 00489 |  16.30s] Skeleton → neutral (1.00)
# [Frame 00490 |  16.33s] Skeleton → neutral (1.00)
# [Frame 00491 |  16.37s] Skeleton → neutral (1.00)
# [Frame 00492 |  16.40s] Skeleton → neutral (1.00)
# [Frame 00493 |  16.43s] Skeleton → neutral (0.98)
# [Frame 00494 |  16.47s] Skeleton → neutral (0.96)
# [Frame 00495 |  16.50s] Skeleton → backhand (0.89)
#            Rejector → backhand prob: 0.10
#            ❌ REJECTED as forehand
# [Frame 00496 |  16.53s] Skeleton → backhand (0.76)
# [Frame 00497 |  16.57s] Skeleton → backhand (0.85)
# [Frame 00498 |  16.60s] Skeleton → backhand (0.70)
# [Frame 00499 |  16.63s] Skeleton → backhand (0.53)
# [Frame 00500 |  16.67s] Skeleton → neutral (0.91)
# [Frame 00501 |  16.70s] Skeleton → neutral (0.92)
# [Frame 00502 |  16.73s] Skeleton → neutral (0.91)
# [Frame 00503 |  16.77s] Skeleton → neutral (0.60)
# [Frame 00504 |  16.80s] Skeleton → neutral (0.64)
# [Frame 00505 |  16.83s] Skeleton → neutral (0.68)
# [Frame 00506 |  16.87s] Skeleton → neutral (0.80)
# [Frame 00507 |  16.90s] Skeleton → neutral (0.93)
# [Frame 00508 |  16.93s] Skeleton → neutral (0.94)
# [Frame 00509 |  16.97s] Skeleton → neutral (0.99)
# [Frame 00510 |  17.00s] Skeleton → neutral (0.68)
# [Frame 00511 |  17.03s] Skeleton → neutral (0.91)
# [Frame 00512 |  17.07s] Skeleton → neutral (0.96)
# [Frame 00513 |  17.10s] Skeleton → neutral (1.00)
# [Frame 00514 |  17.13s] Skeleton → neutral (1.00)
# [Frame 00515 |  17.17s] Skeleton → neutral (1.00)
# [Frame 00516 |  17.20s] Skeleton → neutral (1.00)
# [Frame 00517 |  17.23s] Skeleton → neutral (1.00)
# [Frame 00518 |  17.27s] Skeleton → neutral (1.00)
# [Frame 00519 |  17.30s] Skeleton → neutral (1.00)
# [Frame 00520 |  17.33s] Skeleton → neutral (1.00)
# [Frame 00521 |  17.37s] Skeleton → neutral (1.00)
# [Frame 00522 |  17.40s] Skeleton → neutral (1.00)
# [Frame 00523 |  17.43s] Skeleton → neutral (1.00)
# [Frame 00524 |  17.47s] Skeleton → neutral (1.00)
# [Frame 00525 |  17.50s] Skeleton → neutral (1.00)
# [Frame 00526 |  17.53s] Skeleton → neutral (1.00)
# [Frame 00527 |  17.57s] Skeleton → neutral (1.00)
# [Frame 00528 |  17.60s] Skeleton → neutral (1.00)
# [Frame 00529 |  17.63s] Skeleton → neutral (1.00)
# [Frame 00530 |  17.67s] Skeleton → neutral (1.00)
# [Frame 00531 |  17.70s] Skeleton → neutral (1.00)
# [Frame 00532 |  17.73s] Skeleton → neutral (1.00)
# [Frame 00533 |  17.77s] Skeleton → neutral (1.00)
# [Frame 00534 |  17.80s] Skeleton → neutral (0.88)
# [Frame 00535 |  17.83s] Skeleton → neutral (0.80)
# [Frame 00536 |  17.87s] Skeleton → neutral (0.90)
# [Frame 00537 |  17.90s] Skeleton → neutral (0.90)
# [Frame 00538 |  17.93s] Skeleton → neutral (0.91)
# [Frame 00539 |  17.97s] Skeleton → neutral (0.91)
# [Frame 00540 |  18.00s] Skeleton → neutral (0.90)
# [Frame 00541 |  18.03s] Skeleton → neutral (0.89)
# [Frame 00542 |  18.07s] Skeleton → neutral (0.86)
# [Frame 00543 |  18.10s] Skeleton → neutral (0.58)
# [Frame 00544 |  18.13s] Skeleton → backhand (0.82)
# [Frame 00545 |  18.17s] Skeleton → backhand (0.94)
#            Rejector → backhand prob: 0.87
#            ❌ REJECTED as forehand
# [Frame 00546 |  18.20s] Skeleton → backhand (0.99)
#            Rejector → backhand prob: 0.95
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #4
#
# 🟢 Finished clip #4
#
# [Frame 00606 |  20.20s] Skeleton → neutral (1.00)
# [Frame 00607 |  20.23s] Skeleton → neutral (1.00)
# [Frame 00608 |  20.27s] Skeleton → neutral (0.89)
# [Frame 00609 |  20.30s] Skeleton → neutral (0.84)
# [Frame 00610 |  20.33s] Skeleton → neutral (0.84)
# [Frame 00611 |  20.37s] Skeleton → neutral (0.88)
# [Frame 00612 |  20.40s] Skeleton → neutral (0.91)
# [Frame 00613 |  20.43s] Skeleton → neutral (0.93)
# [Frame 00614 |  20.47s] Skeleton → neutral (0.94)
# [Frame 00615 |  20.50s] Skeleton → neutral (0.95)
# [Frame 00616 |  20.53s] Skeleton → neutral (0.96)
# [Frame 00617 |  20.57s] Skeleton → neutral (0.95)
# [Frame 00618 |  20.60s] Skeleton → neutral (0.94)
# [Frame 00619 |  20.63s] Skeleton → neutral (0.87)
# [Frame 00620 |  20.67s] Skeleton → neutral (0.74)
# [Frame 00621 |  20.70s] Skeleton → backhand (0.59)
# [Frame 00622 |  20.73s] Skeleton → backhand (0.85)
#            Rejector → backhand prob: 0.63
#            ❌ REJECTED as forehand
# [Frame 00623 |  20.77s] Skeleton → backhand (0.94)
#            Rejector → backhand prob: 0.77
#            ❌ REJECTED as forehand
# [Frame 00624 |  20.80s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.91
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip
# [Frame 01363 |  45.43s] Skeleton → neutral (0.99)
# [Frame 01364 |  45.47s] Skeleton → neutral (1.00)
# [Frame 01365 |  45.50s] Skeleton → neutral (1.00)
# [Frame 01366 |  45.53s] Skeleton → neutral (1.00)
# [Frame 01367 |  45.57s] Skeleton → neutral (1.00)
# [Frame 01368 |  45.60s] Skeleton → neutral (1.00)
# [Frame 01369 |  45.63s] Skeleton → neutral (1.00)
# [Frame 01370 |  45.67s] Skeleton → neutral (1.00)
# [Frame 01371 |  45.70s] Skeleton → neutral (1.00)
# [Frame 01372 |  45.73s] Skeleton → neutral (1.00)
# [Frame 01373 |  45.77s] Skeleton → neutral (1.00)
# [Frame 01374 |  45.80s] Skeleton → neutral (1.00)
# [Frame 01375 |  45.83s] Skeleton → neutral (1.00)
# [Frame 01376 |  45.87s] Skeleton → neutral (1.00)
# [Frame 01377 |  45.90s] Skeleton → neutral (1.00)
# [Frame 01378 |  45.93s] Skeleton → neutral (1.00)
# [Frame 01379 |  45.97s] Skeleton → neutral (1.00)
# [Frame 01380 |  46.00s] Skeleton → neutral (1.00)
# [Frame 01381 |  46.03s] Skeleton → neutral (1.00)
# [Frame 01382 |  46.07s] Skeleton → neutral (0.97)
# [Frame 01383 |  46.10s] Skeleton → neutral (0.87)
# [Frame 01384 |  46.13s] Skeleton → neutral (0.84)
# [Frame 01385 |  46.17s] Skeleton → neutral (0.87)
# [Frame 01386 |  46.20s] Skeleton → neutral (0.89)
# [Frame 01387 |  46.23s] Skeleton → neutral (0.91)
# [Frame 01388 |  46.27s] Skeleton → neutral (0.92)
# [Frame 01389 |  46.30s] Skeleton → neutral (0.91)
# [Frame 01390 |  46.33s] Skeleton → neutral (0.85)
# [Frame 01391 |  46.37s] Skeleton → neutral (0.67)
# [Frame 01392 |  46.40s] Skeleton → backhand (0.66)
# [Frame 01393 |  46.43s] Skeleton → backhand (0.88)
#            Rejector → backhand prob: 0.69
#            ❌ REJECTED as forehand
# [Frame 01394 |  46.47s] Skeleton → backhand (0.96)
#            Rejector → backhand prob: 0.81
#            ❌ REJECTED as forehand
# [Frame 01395 |  46.50s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.90
#            ❌ REJECTED as forehand
# [Frame 01396 |  46.53s] Skeleton → backhand (0.99)
#            Rejector → backhand prob: 0.95
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #10
#
# 🟢 Finished clip #10
#
# [Frame 01456 |  48.53s] Skeleton → neutral (1.00)
# [Frame 01457 |  48.57s] Skeleton → neutral (0.99)
# [Frame 01458 |  48.60s] Skeleton → neutral (0.87)
# [Frame 01459 |  48.63s] Skeleton → neutral (0.76)
# [Frame 01460 |  48.67s] Skeleton → neutral (0.74)
# [Frame 01461 |  48.70s] Skeleton → neutral (0.82)
# [Frame 01462 |  48.73s] Skeleton → neutral (0.80)
# [Frame 01463 |  48.77s] Skeleton → neutral (0.73)
# [Frame 01464 |  48.80s] Skeleton → neutral (0.60)
# [Frame 01465 |  48.83s] Skeleton → neutral (0.56)
# [Frame 01466 |  48.87s] Skeleton → backhand (0.52)
# [Frame 01467 |  48.90s] Skeleton → backhand (0.62)
# [Frame 01468 |  48.93s] Skeleton → backhand (0.70)
# [Frame 01469 |  48.97s] Skeleton → backhand (0.78)
# [Frame 01470 |  49.00s] Skeleton → backhand (0.84)
# [Frame 01471 |  49.03s] Skeleton → backhand (0.88)
#            Rejector → backhand prob: 0.82
#            ❌ REJECTED as forehand
# [Frame 01472 |  49.07s] Skeleton → backhand (0.94)
#            Rejector → backhand prob: 0.85
#            ❌ REJECTED as forehand
# [Frame 01473 |  49.10s] Skeleton → backhand (0.98)
#            Rejector → backhand prob: 0.95
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #11
#
# 🟢 Finished clip #11
#
# [Frame 01533 |  51.10s] Skeleton → neutral (1.00)
# [Frame 01534 |  51.13s] Skeleton → neutral (1.00)
# [Frame 01535 |  51.17s] Skeleton → neutral (1.00)
# [Frame 01536 |  51.20s] Skeleton → neutral (1.00)
# [Frame 01537 |  51.23s] Skeleton → neutral (1.00)
# [Frame 01538 |  51.27s] Skeleton → neutral (1.00)
# [Frame 01539 |  51.30s] Skeleton → neutral (1.00)
# [Frame 01540 |  51.33s] Skeleton → neutral (1.00)
# [Frame 01541 |  51.37s] Skeleton → neutral (1.00)
# [Frame 01542 |  51.40s] Skeleton → neutral (1.00)
# [Frame 01543 |  51.43s] Skeleton → neutral (1.00)
# [Frame 01544 |  51.47s] Skeleton → neutral (1.00)
# [Frame 01545 |  51.50s] Skeleton → neutral (1.00)
# [Frame 01546 |  51.53s] Skeleton → neutral (1.00)
# [Frame 01547 |  51.57s] Skeleton → neutral (1.00)
# [Frame 01548 |  51.60s] Skeleton → neutral (1.00)
# [Frame 01549 |  51.63s] Skeleton → neutral (1.00)
# [Frame 01550 |  51.67s] Skeleton → neutral (1.00)
# [Frame 01551 |  51.70s] Skeleton → neutral (1.00)
# [Frame 01552 |  51.73s] Skeleton → neutral (0.95)
# [Frame 01553 |  51.77s] Skeleton → neutral (0.93)
# [Frame 01554 |  51.80s] Skeleton → neutral (0.87)
# [Frame 01555 |  51.83s] Skeleton → neutral (0.71)
# [Frame 01556 |  51.87s] Skeleton → neutral (0.74)
# [Frame 01557 |  51.90s] Skeleton → neutral (0.56)
# [Frame 01558 |  51.93s] Skeleton → neutral (0.56)
# [Frame 01559 |  51.97s] Skeleton → backhand (0.57)
# [Frame 01560 |  52.00s] Skeleton → backhand (0.67)
# [Frame 01561 |  52.03s] Skeleton → backhand (0.68)
# [Frame 01562 |  52.07s] Skeleton → backhand (0.80)
# [Frame 01563 |  52.10s] Skeleton → backhand (0.79)
# [Frame 01564 |  52.13s] Skeleton → backhand (0.90)
#            Rejector → backhand prob: 0.81
#            ❌ REJECTED as forehand
# [Frame 01565 |  52.17s] Skeleton → backhand (0.91)
#            Rejector → backhand prob: 0.82
#            ❌ REJECTED as forehand
# [Frame 01566 |  52.20s] Skeleton → backhand (0.97)
#            Rejector → backhand prob: 0.95
#            ✅ ACCEPTED by rejector
#
# 🎬 Recording clip #12
#
# 🟢 Finished clip #12
#
# [Frame 01626 |  54.20s] Skeleton → neutral (1.00)
# [Frame 01627 |  54.23s] Skeleton → neutral (1.00)
# [Frame 01628 |  54.27s] Skeleton → neutral (1.00)
# [Frame 01629 |  54.30s] Skeleton → neutral (1.00)
# [Frame 01630 |  54.33s] Skeleton → neutral (1.00)
